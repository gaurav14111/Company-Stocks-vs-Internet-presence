# %% [markdown]
# # Project "The relationship between companies' stock prices and their internet presence"

# %% [markdown]
# ## Data preparation

# %%
#Dependencies
#%matplotlib inline

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from scipy import stats
from sklearn.linear_model import LinearRegression

# %%
#Files to load 
stock_data_to_load = "Stock_data.csv"
google_trends_data_to_load = "Google_trends_data.csv"
twitter_data_to_load = "Twitter_data.csv"
news_data_to_load = "News_data.csv"

# Read the data
stock_data = pd.read_csv(stock_data_to_load)
google_trends_data = pd.read_csv(google_trends_data_to_load)
twitter_data = pd.read_csv(twitter_data_to_load)
news_data = pd.read_csv(news_data_to_load)

# %%
stock_data.head()
# Out:
#          date    open    high     low   close    volume Company Name
# 0  2018-04-03  269.82  273.35  254.49  267.53  18844384  Tesla, Inc.
# 1  2018-04-04  252.78  288.37  252.00  286.94  19896746  Tesla, Inc.
# 2  2018-04-05  289.34  306.26  288.20  305.72  19121101  Tesla, Inc.
# 3  2018-04-06  301.00  309.28  295.50  299.30  13520286  Tesla, Inc.
# 4  2018-04-09  300.37  309.50  289.21  289.66  10249805  Tesla, Inc.

# %%
stock_data = stock_data.rename(index=str, columns={"date": "Date"})
stock_data.head()
# Out:
#          Date    open    high     low   close    volume Company Name
# 0  2018-04-03  269.82  273.35  254.49  267.53  18844384  Tesla, Inc.
# 1  2018-04-04  252.78  288.37  252.00  286.94  19896746  Tesla, Inc.
# 2  2018-04-05  289.34  306.26  288.20  305.72  19121101  Tesla, Inc.
# 3  2018-04-06  301.00  309.28  295.50  299.30  13520286  Tesla, Inc.
# 4  2018-04-09  300.37  309.50  289.21  289.66  10249805  Tesla, Inc.

# %%
google_trends_data.head()
# Out:
#          date  Tesla  Netflix  Google  isPartial
# 0  2019-01-02     35       23      38      False
# 1  2019-01-03     15       26      41      False
# 2  2019-01-04     11       30      80      False
# 3  2019-01-05     10       39      34      False
# 4  2019-01-06     27       27      45      False

# %%
#Transform the data for merging
google_trends_data = pd.melt(google_trends_data, id_vars=["date"], 
                  var_name="Search Query", value_name="Popularity Rate")

# %%
google_trends_data.head()
# Out:
#          date Search Query Popularity Rate
# 0  2019-01-02        Tesla              35
# 1  2019-01-03        Tesla              15
# 2  2019-01-04        Tesla              11
# 3  2019-01-05        Tesla              10
# 4  2019-01-06        Tesla              27

# %%
google_trends_data["Company Name"] = ""
google_trends_data.loc[google_trends_data["Search Query"] == "Tesla", "Company Name"] = "Tesla, Inc."
google_trends_data.loc[google_trends_data["Search Query"] == "Google", "Company Name"] = "Google LLC"
google_trends_data.loc[google_trends_data["Search Query"] == "Netflix", "Company Name"] = "Netflix, Inc."

# %%
google_trends_data = google_trends_data.rename(index=str, columns={"date": "Date"})

# %%
google_trends_data.head()
# Out:
#          Date Search Query Popularity Rate Company Name
# 0  2019-01-02        Tesla              35  Tesla, Inc.
# 1  2019-01-03        Tesla              15  Tesla, Inc.
# 2  2019-01-04        Tesla              11  Tesla, Inc.
# 3  2019-01-05        Tesla              10  Tesla, Inc.
# 4  2019-01-06        Tesla              27  Tesla, Inc.

# %%
twitter_data.head()
# Out:
#    index      Date Twitter Account  Total Tweets  Average Compound Score  \
# 0      0  14-06-02   @reedhastings             1                  0.5563
# 1      1  14-08-06   @reedhastings             1                 -0.4019
# 2      2  14-08-24   @reedhastings             2                  0.1806
# 3      3  14-08-25   @reedhastings             1                  0.8957
# 4      4  14-08-26   @reedhastings             1                  0.0000
#
#    Average Positive Score  Average Negative Score  Average Neutral Score  \
# 0                  0.3100                   0.000                 0.6900
# 1                  0.0000                   0.114                 0.8860
# 2                  0.1925                   0.000                 0.8075
# 3                  0.4050                   0.074                 0.5210
# 4                  0.0000                   0.000                 1.0000
#
#    Total Retweets  Total Likes   Company Name
# 0               2            3  Netflix, Inc.
# 1              20            0  Netflix, Inc.
# 2              32            0  Netflix, Inc.
# 3               1            0  Netflix, Inc.
# 4             191            0  Netflix, Inc.

# %%
news_data.head()
# Out:
#          Date Company Name  Total News (per day)  Average Compound Score  \
# 0  2019-03-02  Tesla, Inc.                     1               -0.962300
# 1  2019-03-03   Google LLC                     2                0.089150
# 2  2019-03-04   Google LLC                     1               -0.381800
# 3  2019-03-06  Tesla, Inc.                     1               -0.051600
# 4  2019-03-07  Tesla, Inc.                     3                0.809767
#
#    Average Positive Score  Average Negative Score  Average Neutral Score
# 0                0.052000                0.534000                 0.4140
# 1                0.057500                0.893000                 0.0495
# 2                0.000000                0.917000                 0.0830
# 3                0.042000                0.911000                 0.0470
# 4                0.189667                0.810333                 0.0000

# %%
# Combine the stock data and google trends into a single dataset
stock_vs_google_trends = pd.merge(stock_data, google_trends_data, on=["Date", "Company Name"], how="left")

# %%
#stock_vs_google_trends.reset_index(inplace=True)
stock_vs_google_trends.head()
# Out:
#          Date    open    high     low   close    volume Company Name  \
# 0  2018-04-03  269.82  273.35  254.49  267.53  18844384  Tesla, Inc.
# 1  2018-04-04  252.78  288.37  252.00  286.94  19896746  Tesla, Inc.
# 2  2018-04-05  289.34  306.26  288.20  305.72  19121101  Tesla, Inc.
# 3  2018-04-06  301.00  309.28  295.50  299.30  13520286  Tesla, Inc.
# 4  2018-04-09  300.37  309.50  289.21  289.66  10249805  Tesla, Inc.
#
#   Search Query Popularity Rate
# 0          NaN             NaN
# 1          NaN             NaN
# 2          NaN             NaN
# 3          NaN             NaN
# 4          NaN             NaN

# %%
stock_vs_google_trends = stock_vs_google_trends.dropna()

# %%
stock_vs_google_trends.reset_index(inplace=True)

# %%
stock_vs_google_trends.head()
# Out:
#    index        Date    open    high       low   close    volume Company Name  \
# 0    189  2019-01-02  306.10  315.13  298.8000  310.12  11658648  Tesla, Inc.
# 1    190  2019-01-03  307.00  309.40  297.3800  300.36   6965184  Tesla, Inc.
# 2    191  2019-01-04  306.00  318.00  302.7300  317.69   7394116  Tesla, Inc.
# 3    192  2019-01-07  321.72  336.74  317.7508  334.96   7551225  Tesla, Inc.
# 4    193  2019-01-08  341.96  344.01  327.0200  335.35   7008516  Tesla, Inc.
#
#   Search Query Popularity Rate
# 0        Tesla              35
# 1        Tesla              15
# 2        Tesla              11
# 3        Tesla              17
# 4        Tesla              10

# %%
stock_vs_google_trends.tail()
# Out:
#      index        Date     open      high     low   close   volume  \
# 178    747  2019-03-25  359.000  367.0399  357.44  366.23  8473845
# 179    748  2019-03-26  367.870  368.3800  358.02  359.97  7666475
# 180    749  2019-03-27  361.000  362.4700  350.37  353.37  7852370
# 181    750  2019-03-28  354.485  355.9400  349.20  354.61  4360960
# 182    751  2019-03-29  357.160  358.2500  353.71  356.56  4705636
#
#       Company Name Search Query Popularity Rate
# 178  Netflix, Inc.      Netflix              40
# 179  Netflix, Inc.      Netflix              30
# 180  Netflix, Inc.      Netflix               7
# 181  Netflix, Inc.      Netflix              15
# 182  Netflix, Inc.      Netflix               8

# %% [markdown]
# ## Visualization

# %%
#Relationship between Open Stock Prices and Popularity Rate

tesla_x = stock_vs_google_trends.loc[stock_vs_google_trends["Search Query"] == "Tesla", "Popularity Rate"]
tesla_y = stock_vs_google_trends.loc[stock_vs_google_trends["Search Query"] == "Tesla", "open"]

tesla = plt.scatter(tesla_x, tesla_y, label='Tesla', c="#3CB371")

plt.title("Tesla Open Stock Prices vs Tesla Popularity Rates")
plt.xlabel("Popularity Rates")
plt.ylabel("Open Stock Prices")

plt.grid()

plt.legend()

plt.savefig("Images/Tesla_scatter.png", dpi = 400)

plt.show()

# %%
netflix_x = stock_vs_google_trends.loc[stock_vs_google_trends["Search Query"] == "Netflix", "Popularity Rate"]
netflix_y = stock_vs_google_trends.loc[stock_vs_google_trends["Search Query"] == "Netflix", "open"]

netflix = plt.scatter(netflix_x, netflix_y, label='Netflix', c="#FA8072", edgecolors="#B22222")

plt.title("Netflix Open Stock Prices vs Netflix Popularity Rates")
plt.xlabel("Popularity Rates")
plt.ylabel("Open Stock Prices")

plt.grid()

plt.legend()

plt.savefig("Images/Netflix_scatter.png", dpi = 400)

plt.show()

# %%
google_x = stock_vs_google_trends.loc[stock_vs_google_trends["Search Query"] == "Google", "Popularity Rate"]
google_y = stock_vs_google_trends.loc[stock_vs_google_trends["Search Query"] == "Google", "open"]


google = plt.scatter(google_x, google_y, label='Google', c="#87CEFA", edgecolors="#00BFFF")

plt.title("Google Open Stock Prices vs Google Popularity Rates")
plt.xlabel("Popularity Rates")
plt.ylabel("Open Stock Prices")

plt.grid()

plt.legend()

plt.savefig("Images/Google_scatter.png", dpi = 400)

plt.show()

# %%
tesla_stock_x = stock_vs_google_trends.loc[stock_vs_google_trends["Search Query"] == "Tesla", "Date"]
tesla_stock_y = stock_vs_google_trends.loc[stock_vs_google_trends["Search Query"] == "Tesla", "open"]

tesla_google_trends_x = stock_vs_google_trends.loc[stock_vs_google_trends["Search Query"] == "Tesla", "Date"]
tesla_google_trends_y = stock_vs_google_trends.loc[stock_vs_google_trends["Search Query"] == "Tesla", "Popularity Rate"]


fig, ax = plt.subplots()

tesla_stock, = ax.plot(tesla_stock_x, tesla_stock_y, label='Tesla Stock Open Prices')
tesla_google_trends, = ax.plot(tesla_google_trends_x, tesla_google_trends_y, label='Tesla Popularity Rates')

ax.set(xlabel='Dates', ylabel='Values',
       title='Tesla Stock Prices vs Tesla Popularity Rates')

ax.xaxis.set_major_locator(plt.MaxNLocator(12))

ax.grid()

ax.legend()

fig.autofmt_xdate()

plt.savefig("Images/Tesla_lines.png", dpi = 400)

plt.show()

# %%
netflix_stock_x = stock_vs_google_trends.loc[stock_vs_google_trends["Search Query"] == "Netflix", "Date"]
netflix_stock_y = stock_vs_google_trends.loc[stock_vs_google_trends["Search Query"] == "Netflix", "open"]

netflix_google_trends_x = stock_vs_google_trends.loc[stock_vs_google_trends["Search Query"] == "Netflix", "Date"]
netflix_google_trends_y = stock_vs_google_trends.loc[stock_vs_google_trends["Search Query"] == "Netflix", "Popularity Rate"]

fig, ax = plt.subplots()

netflix_stock, = ax.plot(netflix_stock_x, netflix_stock_y, label='Netflix Stock Open Prices')
netflix_google_trends, = ax.plot(netflix_google_trends_x, netflix_google_trends_y, label='Netflix Popularity Rates')

ax.set(xlabel='Dates', ylabel='Values',
       title='Netflix Stock Prices vs Netflix Popularity Rates')

ax.xaxis.set_major_locator(plt.MaxNLocator(12))

ax.grid()

ax.legend()

fig.autofmt_xdate()

plt.savefig("Images/Netflix_lines.png", dpi = 400)

plt.show()

# %%
google_stock_x = stock_vs_google_trends.loc[stock_vs_google_trends["Search Query"] == "Google", "Date"]
google_stock_y = stock_vs_google_trends.loc[stock_vs_google_trends["Search Query"] == "Google", "open"]

google_comp_trends_x = stock_vs_google_trends.loc[stock_vs_google_trends["Search Query"] == "Google", "Date"]
google_comp_trends_y = stock_vs_google_trends.loc[stock_vs_google_trends["Search Query"] == "Google", "Popularity Rate"]

fig, ax = plt.subplots()

google_stock, = ax.plot(google_stock_x, google_stock_y, label='Google Stock Open Prices')
google_comp_trends, = ax.plot(google_comp_trends_x, google_comp_trends_y, label='Google Popularity Rates')

ax.set(xlabel='Dates', ylabel='Values',
       title='Google Stock Prices vs Google Popularity Rates')

ax.xaxis.set_major_locator(plt.MaxNLocator(12))

ax.grid()

ax.legend()

fig.autofmt_xdate()

plt.savefig("Images/Google_lines.png", dpi = 400)

plt.show()

# %% [markdown]
# ## Statistics

# %%
# Combine the data into a single dataset (outer join)

df_step_1 = pd.merge(stock_data, google_trends_data, on=["Date", "Company Name"], how="outer")

df_step_2 = pd.merge(df_step_1, twitter_data, on=["Date", "Company Name"], how="outer")

combined_data_outer_join = pd.merge(df_step_2, news_data, on=["Date", "Company Name"], how="outer", suffixes=('', '_news'))

# %%
combined_data_outer_join
# Out:
#             Date      open      high       low    close      volume  \
# 0     2018-04-03  269.8200  273.3500  254.4900  267.530  18844384.0
# 1     2018-04-04  252.7800  288.3700  252.0000  286.940  19896746.0
# 2     2018-04-05  289.3400  306.2600  288.2000  305.720  19121101.0
# 3     2018-04-06  301.0000  309.2800  295.5000  299.300  13520286.0
# 4     2018-04-09  300.3700  309.5000  289.2100  289.660  10249805.0
# 5     2018-04-10  298.9700  307.1000  293.6800  304.700  11024259.0
# 6     2018-04-11  300.7403  308.9800  299.6600  300.930   7482945.0
# 7     2018-04-12  302.3200  303.9500  293.6800  294.080   7608769.0
# 8     2018-04-13  303.6000  303.9499  295.9800  300.340   7327223.0
# 9     2018-04-16  299.0000  299.6600  289.0100  291.210   6338488.0
# 10    2018-04-17  288.8700  292.1700  282.5100  287.690   7000023.0
# 11    2018-04-18  291.0800  300.2400  288.1600  293.350   6557700.0
# 12    2018-04-19  291.0800  301.0100  288.5500  300.080   6090599.0
# 13    2018-04-20  295.1700  299.9800  289.7500  290.240   5627928.0
# 14    2018-04-23  291.2900  291.6200  282.3300  283.370   4893378.0
# 15    2018-04-24  285.0000  287.0900  278.4600  283.460   5685308.0
# 16    2018-04-25  283.5000  285.1600  277.2500  280.690   4013574.0
# 17    2018-04-26  278.7500  285.7900  276.5000  285.480   4356013.0
# 18    2018-04-27  285.3700  294.4700  283.8300  294.075   4364626.0
# 19    2018-04-30  293.6100  298.7300  292.5000  293.900   4228172.0
# 20    2018-05-01  293.5100  300.8200  293.2200  299.920   4625603.0
# 21    2018-05-02  298.5700  306.8500  297.7844  301.150   8970370.0
# 22    2018-05-03  278.7900  288.0400  275.2300  284.450  17352130.0
# 23    2018-05-04  283.0000  296.8600  279.5200  294.090   8569354.0
# 24    2018-05-07  297.5000  305.9588  295.1700  302.770   8678224.0
# 25    2018-05-08  300.7953  307.7500  299.0000  301.970   5930000.0
# 26    2018-05-09  300.4100  307.0100  300.0500  306.850   5727365.0
# 27    2018-05-10  307.4997  312.9900  304.1119  305.020   5651561.0
# 28    2018-05-11  307.7000  308.8800  299.0800  301.060   4679649.0
# 29    2018-05-14  303.3200  304.9400  291.6200  291.970   7286804.0
# ...          ...       ...       ...       ...      ...         ...
# 1117    19-03-01       NaN       NaN       NaN      NaN         NaN
# 1118    19-03-02       NaN       NaN       NaN      NaN         NaN
# 1119    19-03-06       NaN       NaN       NaN      NaN         NaN
# 1120    19-03-08       NaN       NaN       NaN      NaN         NaN
# 1121    19-03-09       NaN       NaN       NaN      NaN         NaN
# 1122    19-03-11       NaN       NaN       NaN      NaN         NaN
# 1123    19-03-12       NaN       NaN       NaN      NaN         NaN
# 1124    19-03-13       NaN       NaN       NaN      NaN         NaN
# 1125    19-03-14       NaN       NaN       NaN      NaN         NaN
# 1126    19-03-15       NaN       NaN       NaN      NaN         NaN
# 1127    19-03-16       NaN       NaN       NaN      NaN         NaN
# 1128    19-03-17       NaN       NaN       NaN      NaN         NaN
# 1129    19-03-18       NaN       NaN       NaN      NaN         NaN
# 1130    19-03-19       NaN       NaN       NaN      NaN         NaN
# 1131    19-03-20       NaN       NaN       NaN      NaN         NaN
# 1132    19-03-21       NaN       NaN       NaN      NaN         NaN
# 1133    19-03-22       NaN       NaN       NaN      NaN         NaN
# 1134    19-03-23       NaN       NaN       NaN      NaN         NaN
# 1135    19-03-24       NaN       NaN       NaN      NaN         NaN
# 1136    19-03-25       NaN       NaN       NaN      NaN         NaN
# 1137    19-03-26       NaN       NaN       NaN      NaN         NaN
# 1138    19-03-27       NaN       NaN       NaN      NaN         NaN
# 1139    19-03-28       NaN       NaN       NaN      NaN         NaN
# 1140    19-03-29       NaN       NaN       NaN      NaN         NaN
# 1141    19-03-30       NaN       NaN       NaN      NaN         NaN
# 1142    19-03-31       NaN       NaN       NaN      NaN         NaN
# 1143    19-04-01       NaN       NaN       NaN      NaN         NaN
# 1144    19-04-02       NaN       NaN       NaN      NaN         NaN
# 1145  2019-03-30       NaN       NaN       NaN      NaN         NaN
# 1146  2019-03-31       NaN       NaN       NaN      NaN         NaN
#
#        Company Name Search Query Popularity Rate  index  \
# 0       Tesla, Inc.          NaN             NaN    NaN
# 1       Tesla, Inc.          NaN             NaN    NaN
# 2       Tesla, Inc.          NaN             NaN    NaN
# 3       Tesla, Inc.          NaN             NaN    NaN
# 4       Tesla, Inc.          NaN             NaN    NaN
# 5       Tesla, Inc.          NaN             NaN    NaN
# 6       Tesla, Inc.          NaN             NaN    NaN
# 7       Tesla, Inc.          NaN             NaN    NaN
# 8       Tesla, Inc.          NaN             NaN    NaN
# 9       Tesla, Inc.          NaN             NaN    NaN
# 10      Tesla, Inc.          NaN             NaN    NaN
# 11      Tesla, Inc.          NaN             NaN    NaN
# 12      Tesla, Inc.          NaN             NaN    NaN
# 13      Tesla, Inc.          NaN             NaN    NaN
# 14      Tesla, Inc.          NaN             NaN    NaN
# 15      Tesla, Inc.          NaN             NaN    NaN
# 16      Tesla, Inc.          NaN             NaN    NaN
# 17      Tesla, Inc.          NaN             NaN    NaN
# 18      Tesla, Inc.          NaN             NaN    NaN
# 19      Tesla, Inc.          NaN             NaN    NaN
# 20      Tesla, Inc.          NaN             NaN    NaN
# 21      Tesla, Inc.          NaN             NaN    NaN
# 22      Tesla, Inc.          NaN             NaN    NaN
# 23      Tesla, Inc.          NaN             NaN    NaN
# 24      Tesla, Inc.          NaN             NaN    NaN
# 25      Tesla, Inc.          NaN             NaN    NaN
# 26      Tesla, Inc.          NaN             NaN    NaN
# 27      Tesla, Inc.          NaN             NaN    NaN
# 28      Tesla, Inc.          NaN             NaN    NaN
# 29      Tesla, Inc.          NaN             NaN    NaN
# ...             ...          ...             ...    ...
# 1117  Netflix, Inc.          NaN             NaN  199.0
# 1118     Google LLC          NaN             NaN  200.0
# 1119     Google LLC          NaN             NaN  201.0
# 1120     Google LLC          NaN             NaN  202.0
# 1121     Google LLC          NaN             NaN  203.0
# 1122     Google LLC          NaN             NaN  204.0
# 1123    Tesla, Inc.          NaN             NaN  205.0
# 1124    Tesla, Inc.          NaN             NaN  206.0
# 1125    Tesla, Inc.          NaN             NaN  207.0
# 1126    Tesla, Inc.          NaN             NaN  208.0
# 1127    Tesla, Inc.          NaN             NaN  209.0
# 1128    Tesla, Inc.          NaN             NaN  210.0
# 1129    Tesla, Inc.          NaN             NaN  211.0
# 1130    Tesla, Inc.          NaN             NaN  212.0
# 1131    Tesla, Inc.          NaN             NaN  213.0
# 1132    Tesla, Inc.          NaN             NaN  214.0
# 1133    Tesla, Inc.          NaN             NaN  215.0
# 1134    Tesla, Inc.          NaN             NaN  216.0
# 1135    Tesla, Inc.          NaN             NaN  217.0
# 1136    Tesla, Inc.          NaN             NaN  218.0
# 1137    Tesla, Inc.          NaN             NaN  219.0
# 1138    Tesla, Inc.          NaN             NaN  220.0
# 1139    Tesla, Inc.          NaN             NaN  221.0
# 1140    Tesla, Inc.          NaN             NaN  222.0
# 1141    Tesla, Inc.          NaN             NaN  223.0
# 1142    Tesla, Inc.          NaN             NaN  224.0
# 1143    Tesla, Inc.          NaN             NaN  225.0
# 1144    Tesla, Inc.          NaN             NaN  226.0
# 1145    Tesla, Inc.          NaN             NaN    NaN
# 1146     Google LLC          NaN             NaN    NaN
#
#                  ...             Average Positive Score  \
# 0                ...                                NaN
# 1                ...                                NaN
# 2                ...                                NaN
# 3                ...                                NaN
# 4                ...                                NaN
# 5                ...                                NaN
# 6                ...                                NaN
# 7                ...                                NaN
# 8                ...                                NaN
# 9                ...                                NaN
# 10               ...                                NaN
# 11               ...                                NaN
# 12               ...                                NaN
# 13               ...                                NaN
# 14               ...                                NaN
# 15               ...                                NaN
# 16               ...                                NaN
# 17               ...                                NaN
# 18               ...                                NaN
# 19               ...                                NaN
# 20               ...                                NaN
# 21               ...                                NaN
# 22               ...                                NaN
# 23               ...                                NaN
# 24               ...                                NaN
# 25               ...                                NaN
# 26               ...                                NaN
# 27               ...                                NaN
# 28               ...                                NaN
# 29               ...                                NaN
# ...              ...                                ...
# 1117             ...                           0.313000
# 1118             ...                           0.226000
# 1119             ...                           0.141000
# 1120             ...                           0.178500
# 1121             ...                           0.111000
# 1122             ...                           0.123000
# 1123             ...                           0.091077
# 1124             ...                           0.050571
# 1125             ...                           0.087875
# 1126             ...                           0.090000
# 1127             ...                           0.080105
# 1128             ...                           0.102333
# 1129             ...                           0.191000
# 1130             ...                           0.000000
# 1131             ...                           0.042429
# 1132             ...                           0.146400
# 1133             ...                           0.230750
# 1134             ...                           0.000000
# 1135             ...                           0.153250
# 1136             ...                           0.226750
# 1137             ...                           0.221846
# 1138             ...                           0.261333
# 1139             ...                           0.113750
# 1140             ...                           0.277000
# 1141             ...                           0.098094
# 1142             ...                           0.183200
# 1143             ...                           0.183294
# 1144             ...                           0.000000
# 1145             ...                                NaN
# 1146             ...                                NaN
#
#       Average Negative Score  Average Neutral Score  Total Retweets  \
# 0                        NaN                    NaN             NaN
# 1                        NaN                    NaN             NaN
# 2                        NaN                    NaN             NaN
# 3                        NaN                    NaN             NaN
# 4                        NaN                    NaN             NaN
# 5                        NaN                    NaN             NaN
# 6                        NaN                    NaN             NaN
# 7                        NaN                    NaN             NaN
# 8                        NaN                    NaN             NaN
# 9                        NaN                    NaN             NaN
# 10                       NaN                    NaN             NaN
# 11                       NaN                    NaN             NaN
# 12                       NaN                    NaN             NaN
# 13                       NaN                    NaN             NaN
# 14                       NaN                    NaN             NaN
# 15                       NaN                    NaN             NaN
# 16                       NaN                    NaN             NaN
# 17                       NaN                    NaN             NaN
# 18                       NaN                    NaN             NaN
# 19                       NaN                    NaN             NaN
# 20                       NaN                    NaN             NaN
# 21                       NaN                    NaN             NaN
# 22                       NaN                    NaN             NaN
# 23                       NaN                    NaN             NaN
# 24                       NaN                    NaN             NaN
# 25                       NaN                    NaN             NaN
# 26                       NaN                    NaN             NaN
# 27                       NaN                    NaN             NaN
# 28                       NaN                    NaN             NaN
# 29                       NaN                    NaN             NaN
# ...                      ...                    ...             ...
# 1117                0.000000               0.687000             0.0
# 1118                0.000000               0.774000            66.0
# 1119                0.000000               0.859000           296.0
# 1120                0.000000               0.821500          1179.0
# 1121                0.000000               0.889000           121.0
# 1122                0.000000               0.877000           457.0
# 1123                0.041231               0.867692          2922.0
# 1124                0.028857               0.920571          2079.0
# 1125                0.032500               0.879750         50707.0
# 1126                0.051857               0.858286          3660.0
# 1127                0.031105               0.888842         22035.0
# 1128                0.025429               0.872238         17763.0
# 1129                0.000000               0.809000          1376.0
# 1130                0.000000               1.000000         14010.0
# 1131                0.019286               0.938143         24394.0
# 1132                0.059400               0.794200          2509.0
# 1133                0.042917               0.726333          4175.0
# 1134                0.000000               1.000000           753.0
# 1135                0.008375               0.838250          3552.0
# 1136                0.056500               0.716750          4900.0
# 1137                0.040692               0.737385          9468.0
# 1138                0.057500               0.681167          2327.0
# 1139                0.038000               0.848250          2015.0
# 1140                0.025889               0.697111          4454.0
# 1141                0.138063               0.763781         84912.0
# 1142                0.023600               0.793000          2640.0
# 1143                0.041647               0.775059         11541.0
# 1144                0.688000               0.312000           248.0
# 1145                     NaN                    NaN             NaN
# 1146                     NaN                    NaN             NaN
#
#       Total Likes  Total News (per day)  Average Compound Score_news  \
# 0             NaN                   NaN                          NaN
# 1             NaN                   NaN                          NaN
# 2             NaN                   NaN                          NaN
# 3             NaN                   NaN                          NaN
# 4             NaN                   NaN                          NaN
# 5             NaN                   NaN                          NaN
# 6             NaN                   NaN                          NaN
# 7             NaN                   NaN                          NaN
# 8             NaN                   NaN                          NaN
# 9             NaN                   NaN                          NaN
# 10            NaN                   NaN                          NaN
# 11            NaN                   NaN                          NaN
# 12            NaN                   NaN                          NaN
# 13            NaN                   NaN                          NaN
# 14            NaN                   NaN                          NaN
# 15            NaN                   NaN                          NaN
# 16            NaN                   NaN                          NaN
# 17            NaN                   NaN                          NaN
# 18            NaN                   NaN                          NaN
# 19            NaN                   NaN                          NaN
# 20            NaN                   NaN                          NaN
# 21            NaN                   NaN                          NaN
# 22            NaN                   NaN                          NaN
# 23            NaN                   NaN                          NaN
# 24            NaN                   NaN                          NaN
# 25            NaN                   NaN                          NaN
# 26            NaN                   NaN                          NaN
# 27            NaN                   NaN                          NaN
# 28            NaN                   NaN                          NaN
# 29            NaN                   NaN                          NaN
# ...           ...                   ...                          ...
# 1117          3.0                   NaN                          NaN
# 1118          0.0                   NaN                          NaN
# 1119       1752.0                   NaN                          NaN
# 1120       9869.0                   NaN                          NaN
# 1121          0.0                   NaN                          NaN
# 1122       2679.0                   NaN                          NaN
# 1123      44335.0                   NaN                          NaN
# 1124      13923.0                   NaN                          NaN
# 1125     302748.0                   NaN                          NaN
# 1126      68694.0                   NaN                          NaN
# 1127     186928.0                   NaN                          NaN
# 1128     215568.0                   NaN                          NaN
# 1129          0.0                   NaN                          NaN
# 1130       5095.0                   NaN                          NaN
# 1131       1227.0                   NaN                          NaN
# 1132      24661.0                   NaN                          NaN
# 1133      47364.0                   NaN                          NaN
# 1134          0.0                   NaN                          NaN
# 1135      70269.0                   NaN                          NaN
# 1136      38994.0                   NaN                          NaN
# 1137     137881.0                   NaN                          NaN
# 1138      19227.0                   NaN                          NaN
# 1139      14111.0                   NaN                          NaN
# 1140      27522.0                   NaN                          NaN
# 1141     887546.0                   NaN                          NaN
# 1142      45330.0                   NaN                          NaN
# 1143     132026.0                   NaN                          NaN
# 1144       5844.0                   NaN                          NaN
# 1145          NaN                   1.0                      -0.0772
# 1146          NaN                   1.0                       0.4019
#
#       Average Positive Score_news  Average Negative Score_news  \
# 0                             NaN                          NaN
# 1                             NaN                          NaN
# 2                             NaN                          NaN
# 3                             NaN                          NaN
# 4                             NaN                          NaN
# 5                             NaN                          NaN
# 6                             NaN                          NaN
# 7                             NaN                          NaN
# 8                             NaN                          NaN
# 9                             NaN                          NaN
# 10                            NaN                          NaN
# 11                            NaN                          NaN
# 12                            NaN                          NaN
# 13                            NaN                          NaN
# 14                            NaN                          NaN
# 15                            NaN                          NaN
# 16                            NaN                          NaN
# 17                            NaN                          NaN
# 18                            NaN                          NaN
# 19                            NaN                          NaN
# 20                            NaN                          NaN
# 21                            NaN                          NaN
# 22                            NaN                          NaN
# 23                            NaN                          NaN
# 24                            NaN                          NaN
# 25                            NaN                          NaN
# 26                            NaN                          NaN
# 27                            NaN                          NaN
# 28                            NaN                          NaN
# 29                            NaN                          NaN
# ...                           ...                          ...
# 1117                          NaN                          NaN
# 1118                          NaN                          NaN
# 1119                          NaN                          NaN
# 1120                          NaN                          NaN
# 1121                          NaN                          NaN
# 1122                          NaN                          NaN
# 1123                          NaN                          NaN
# 1124                          NaN                          NaN
# 1125                          NaN                          NaN
# 1126                          NaN                          NaN
# 1127                          NaN                          NaN
# 1128                          NaN                          NaN
# 1129                          NaN                          NaN
# 1130                          NaN                          NaN
# 1131                          NaN                          NaN
# 1132                          NaN                          NaN
# 1133                          NaN                          NaN
# 1134                          NaN                          NaN
# 1135                          NaN                          NaN
# 1136                          NaN                          NaN
# 1137                          NaN                          NaN
# 1138                          NaN                          NaN
# 1139                          NaN                          NaN
# 1140                          NaN                          NaN
# 1141                          NaN                          NaN
# 1142                          NaN                          NaN
# 1143                          NaN                          NaN
# 1144                          NaN                          NaN
# 1145                        0.053                        0.887
# 1146                        0.060                        0.940
#
#       Average Neutral Score_news
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN
# 5                            NaN
# 6                            NaN
# 7                            NaN
# 8                            NaN
# 9                            NaN
# 10                           NaN
# 11                           NaN
# 12                           NaN
# 13                           NaN
# 14                           NaN
# 15                           NaN
# 16                           NaN
# 17                           NaN
# 18                           NaN
# 19                           NaN
# 20                           NaN
# 21                           NaN
# 22                           NaN
# 23                           NaN
# 24                           NaN
# 25                           NaN
# 26                           NaN
# 27                           NaN
# 28                           NaN
# 29                           NaN
# ...                          ...
# 1117                         NaN
# 1118                         NaN
# 1119                         NaN
# 1120                         NaN
# 1121                         NaN
# 1122                         NaN
# 1123                         NaN
# 1124                         NaN
# 1125                         NaN
# 1126                         NaN
# 1127                         NaN
# 1128                         NaN
# 1129                         NaN
# 1130                         NaN
# 1131                         NaN
# 1132                         NaN
# 1133                         NaN
# 1134                         NaN
# 1135                         NaN
# 1136                         NaN
# 1137                         NaN
# 1138                         NaN
# 1139                         NaN
# 1140                         NaN
# 1141                         NaN
# 1142                         NaN
# 1143                         NaN
# 1144                         NaN
# 1145                        0.06
# 1146                        0.00
#
# [1147 rows x 23 columns]

# %%
# Combine the stock data and news data into a single dataset

stock_news_data = pd.merge(stock_data, news_data, on=["Date", "Company Name"], how="inner")

# %%
stock_news_data
# Out:
#           Date     open       high        low    close    volume  \
# 0   2019-03-06   276.48   281.5058   274.3900   276.24  10335485
# 1   2019-03-07   278.84   284.7000   274.2500   276.59   9442483
# 2   2019-03-11   283.52   291.2800   280.5000   290.92   7392278
# 3   2019-03-15   283.51   283.7244   274.4000   275.43  14785531
# 4   2019-03-18   276.00   278.0500   267.3000   269.49  10280980
# 5   2019-03-21   272.60   276.4500   268.4500   274.02   5947098
# 6   2019-03-25   259.71   263.1800   254.4600   260.42  10215029
# 7   2019-03-27   268.75   275.3700   268.1838   274.83   8779166
# 8   2019-03-04  1154.56  1165.5200  1138.2500  1153.42   1774467
# 9   2019-03-12  1182.30  1205.7100  1182.3000  1197.25   2110979
# 10  2019-03-13  1205.93  1207.1200  1197.9100  1199.06   1294354
# 11  2019-03-14  1199.02  1204.7000  1191.2300  1192.53   1365072
# 12  2019-03-19  1191.72  1203.4000  1189.4600  1202.46   1489407
# 13  2019-03-20  1201.40  1229.9900  1199.5900  1226.43   2075442
# 14  2019-03-28  1175.50  1177.2500  1163.4300  1172.27   1120122
# 15  2019-03-29  1180.18  1183.9700  1166.3800  1176.89   1544615
# 16  2019-04-01  1187.54  1200.2000  1186.3600  1198.98   1385595
# 17  2019-03-08   345.75   349.9200   342.4700   349.60   6898838
# 18  2019-03-22   375.95   376.4300   360.0400   361.01   8661346
#
#      Company Name  Total News (per day)  Average Compound Score  \
# 0     Tesla, Inc.                     1               -0.051600
# 1     Tesla, Inc.                     3                0.809767
# 2     Tesla, Inc.                     3                0.224367
# 3     Tesla, Inc.                     2                0.051250
# 4     Tesla, Inc.                     2                0.179150
# 5     Tesla, Inc.                     2               -0.113150
# 6     Tesla, Inc.                     2                0.044500
# 7     Tesla, Inc.                     4               -0.127450
# 8      Google LLC                     1               -0.381800
# 9      Google LLC                     2                0.560900
# 10     Google LLC                     1                0.796400
# 11     Google LLC                     4               -0.522175
# 12     Google LLC                     6                0.401933
# 13     Google LLC                     2                0.359200
# 14     Google LLC                     2                0.545000
# 15     Google LLC                     3                0.068200
# 16     Google LLC                     4                0.270450
# 17  Netflix, Inc.                     1                0.624900
# 18  Netflix, Inc.                     2                0.073500
#
#     Average Positive Score  Average Negative Score  Average Neutral Score
# 0                 0.042000                0.911000               0.047000
# 1                 0.189667                0.810333               0.000000
# 2                 0.035333                0.964667               0.000000
# 3                 0.090000                0.833000               0.076500
# 4                 0.145000                0.830500               0.024500
# 5                 0.029500                0.898500               0.072000
# 6                 0.058000                0.912000               0.030000
# 7                 0.011000                0.919500               0.069500
# 8                 0.000000                0.917000               0.083000
# 9                 0.116000                0.861000               0.023000
# 10                0.176000                0.824000               0.000000
# 11                0.062250                0.763750               0.174000
# 12                0.149500                0.807500               0.042833
# 13                0.081000                0.919000               0.000000
# 14                0.097500                0.902500               0.000000
# 15                0.094000                0.779333               0.127000
# 16                0.134750                0.810500               0.054750
# 17                0.085000                0.915000               0.000000
# 18                0.096500                0.824500               0.078500

# %%
tesla_stock_news = stock_news_data.loc[stock_news_data["Company Name"] == "Tesla, Inc.", ["Date", "open", "Total News (per day)", "Average Positive Score", "Average Negative Score", "Average Neutral Score"]]

# %%
tesla_stock_news
# Out:
#          Date    open  Total News (per day)  Average Positive Score  \
# 0  2019-03-06  276.48                     1                0.042000
# 1  2019-03-07  278.84                     3                0.189667
# 2  2019-03-11  283.52                     3                0.035333
# 3  2019-03-15  283.51                     2                0.090000
# 4  2019-03-18  276.00                     2                0.145000
# 5  2019-03-21  272.60                     2                0.029500
# 6  2019-03-25  259.71                     2                0.058000
# 7  2019-03-27  268.75                     4                0.011000
#
#    Average Negative Score  Average Neutral Score
# 0                0.911000                 0.0470
# 1                0.810333                 0.0000
# 2                0.964667                 0.0000
# 3                0.833000                 0.0765
# 4                0.830500                 0.0245
# 5                0.898500                 0.0720
# 6                0.912000                 0.0300
# 7                0.919500                 0.0695

# %%
#Linear regression

# %%
#For Tesla 
X = tesla_stock_news.drop(['open', 'Date'], axis=1)
y = tesla_stock_news['open']

# X = stock_vs_google_trends.loc[stock_vs_google_trends["Search Query"] == "Tesla", "Popularity Rate"]
# y = stock_vs_google_trends.loc[stock_vs_google_trends["Search Query"] == "Tesla", "open"]

# %%
model = LinearRegression()
model.fit(X, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
print('R^2: {0}'.format(model.score(X, y)))
# Out:
# R^2: 0.3757531803226846

# %%
coef = pd.DataFrame(list(zip(['intercept'] + X.columns.tolist(), [model.intercept_] + model.coef_.tolist())),
                    columns=['predictor', 'coef'])
coef
# Out:
#                 predictor          coef
# 0               intercept  30917.796214
# 1    Total News (per day)      0.115526
# 2  Average Positive Score -30643.370749
# 3  Average Negative Score -30639.620198
# 4   Average Neutral Score -30768.761743
