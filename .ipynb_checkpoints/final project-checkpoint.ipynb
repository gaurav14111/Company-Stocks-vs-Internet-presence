# %%
# Dependencies
import tweepy
import matplotlib.pyplot as plt
import pandas as pd
import json
import numpy as np
#import tim
import datetime
from iex import Stock
from pytrends.request import TrendReq
from config 
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# %%
# Twitter API Keys
from config import consumer_key, consumer_secret, access_token, access_token_secret

# Twitter credentials
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())

# %%
# Create columns for dataframe
tweets_table = {
                'Tweet Number': '',
                'PersonTweeted': '',
                'Tweet': '',
                'Compound Score': '',
                'Positive Score': '',
                'Negative Score': '',
                'Neutral Score': ''}
# Create list of news accounts
target_terms = ['@elonmusk', '@JeffBezos', '@sundarpichai', '@reedhastings', '@WarrenBuffett', '@narendramodi', '@theresa_may']

# Variable to hold list of the compound sentiment
compound_list = []
positive_list = []
negative_list = []
neutral_list = []
tweet_number = []
person_tweeted = []
text = []
created =[]
retweet = []
likes = [] 

# 'retweeted_status': {'created_at': 'Thu Mar 28 19:02:10 +0000 2019',
#    'id': 1111342735066365952,
#    'id_str': '1111342735066365952',
#    'text': 'CEO Spotlight: @SteveForbesCEO, Chairman @Forbes joins @NPetallides live from the @Nasdaq Market Site.',
      
# Loop through all target users
for target in target_terms:
        
    # Run search around each tweet(Upto max of 200 tweets at once)
    screen_name = target
    public_tweets = api.user_timeline(target, count=200,result_type ="recent")

    
    # Index to see how many tweets for each news source
    index = 0
        
    # Loop through all tweets
    
    for tweet in public_tweets:
        
        news_organization = target
            
        # Run vader analysis on each tweet
        
        scores = analyzer.polarity_scores(tweet['text'])
        compound = scores['compound']
        pos = scores['pos']
        neu = scores['neu']
        neg = scores['neg']
            
        # Append values to empty lists
        
        compound_list.append(compound)
        positive_list.append(pos)
        negative_list.append(neg)
        neutral_list.append(neu)
        text.append(tweet['text'])
        tweet_number.append(index)
        person_tweeted.append(target)
        tweet_date = datetime.datetime.strptime(tweet["created_at"], "%a %b %d %H:%M:%S %z %Y")
        convert_time = datetime.datetime.strftime(tweet_date, '%y-%m-%d')
        created.append(convert_time)
        retweet.append(tweet["retweet_count"])
        likes.append(tweet["favorite_count"])      
        index = index + 1
#Create dataframe from the lists appended above 

tweets_table = {
                'Person_Tweeted' : person_tweeted,
                'Tweet Number' : tweet_number,
                'Tweet' : text,
                'Compound Score' : compound_list,
                'Positive Score': positive_list,
                'Negative Score': negative_list,
                'Date': created,
                'Retweet' : retweet,
                'Likes' : likes
                
}

tweets_table = pd.DataFrame(tweets_table)
tweets_table
# Out:
#      Person_Tweeted  Tweet Number  \
# 0         @elonmusk             0
# 1         @elonmusk             1
# 2         @elonmusk             2
# 3         @elonmusk             3
# 4         @elonmusk             4
# 5         @elonmusk             5
# 6         @elonmusk             6
# 7         @elonmusk             7
# 8         @elonmusk             8
# 9         @elonmusk             9
# 10        @elonmusk            10
# 11        @elonmusk            11
# 12        @elonmusk            12
# 13        @elonmusk            13
# 14        @elonmusk            14
# 15        @elonmusk            15
# 16        @elonmusk            16
# 17        @elonmusk            17
# 18        @elonmusk            18
# 19        @elonmusk            19
# 20        @elonmusk            20
# 21        @elonmusk            21
# 22        @elonmusk            22
# 23        @elonmusk            23
# 24        @elonmusk            24
# 25        @elonmusk            25
# 26        @elonmusk            26
# 27        @elonmusk            27
# 28        @elonmusk            28
# 29        @elonmusk            29
# ...             ...           ...
# 1053   @theresa_may           170
# 1054   @theresa_may           171
# 1055   @theresa_may           172
# 1056   @theresa_may           173
# 1057   @theresa_may           174
# 1058   @theresa_may           175
# 1059   @theresa_may           176
# 1060   @theresa_may           177
# 1061   @theresa_may           178
# 1062   @theresa_may           179
# 1063   @theresa_may           180
# 1064   @theresa_may           181
# 1065   @theresa_may           182
# 1066   @theresa_may           183
# 1067   @theresa_may           184
# 1068   @theresa_may           185
# 1069   @theresa_may           186
# 1070   @theresa_may           187
# 1071   @theresa_may           188
# 1072   @theresa_may           189
# 1073   @theresa_may           190
# 1074   @theresa_may           191
# 1075   @theresa_may           192
# 1076   @theresa_may           193
# 1077   @theresa_may           194
# 1078   @theresa_may           195
# 1079   @theresa_may           196
# 1080   @theresa_may           197
# 1081   @theresa_may           198
# 1082   @theresa_may           199
#
#                                                   Tweet  Compound Score  \
# 0             @saraccbleitao @Tesla Pre-Happy birthday!          0.0000
# 1     Amazing work by Tesla Delivery teams, especial...          0.3945
# 2                                  @MoWo91 Coming soon!          0.0000
# 3                                         @sdpilgrim No         -0.2960
# 4                                        @Teslarati Wow          0.5859
# 5                     @annerajb https://t.co/TKkruvyckP          0.0000
# 6                          This might be my finest work          0.0000
# 7     Duck emoji defeats Emo G Records. Crushing vic...         -0.5859
# 8          I’m disappointed that my record label failed         -0.7506
# 9     Emo G Records\nhttps://t.co/zsuB2NDl48 https:/...          0.0000
# 10    @TechVelocirap @FewellJacob @WorldAndScience I...          0.0000
# 11              @FewellJacob @WorldAndScience Also true          0.4215
# 12                    @HConcience @WorldAndScience True          0.4215
# 13                  The quality of emojis varies wildly          0.0000
# 14                                                 Lame         -0.4215
# 15                                                    🦆          0.0000
# 16                    @WorldAndScience C++ syntax sucks         -0.3612
# 17    @WorldAndScience Assert (“Money” == Series of ...         -0.3400
# 18    @martinengwicht @Erdayastronaut @DiscoverMag E...         -0.4199
# 19    @marshgre @NickBre58305797 @letsrebel1 @paul_r...          0.4939
# 20    @martinengwicht @flcnhvy @Erdayastronaut @Disc...          0.3903
# 21    @TesLatino @mcjamez @TeslaAnswers @flcnhvy @Er...         -0.2023
# 22    @TeslaAnswers @flcnhvy @Erdayastronaut @Discov...          0.0000
# 23    @flcnhvy @Erdayastronaut @DiscoverMag Annoying...         -0.4019
# 24    @flcnhvy @Erdayastronaut @DiscoverMag Yeah, Fa...         -0.1779
# 25    @Erdayastronaut @DiscoverMag Probably no fairi...         -0.2960
# 26    @emilmelar Retrofits will start when our softw...          0.5106
# 27        @MacBenTosh Anyone who bought FSD will get it          0.0000
# 28    Anyone who purchased full self-driving will ge...          0.5106
# 29    @nextspaceflight @Erdayastronaut @DiscoverMag ...          0.7783
# ...                                                 ...             ...
# 1053  RT @10DowningStreet: PM @Theresa_May is in Bru...          0.0000
# 1054  Labour’s policies would be devastating to busi...         -0.6486
# 1055  Shocked and saddened by the terrible attack in...         -0.9100
# 1056  RT @10DowningStreet: PM @Theresa_May continues...          0.0000
# 1057  RT @10DowningStreet: PM @Theresa_May is meetin...          0.0000
# 2018-12-09      9       10      28     False
# 2018-12-16     11       11      28     False
# 2018-12-23     11       18      28     False
# 2018-12-30     12       16      23     False
# 2019-01-06      8       16      24     False
# 2019-01-13      9       20      22     False
# 2019-01-20     10       17      25     False
# 2019-01-27     11       13      24     False
# 2019-02-03     10       16      25     False
# 2019-02-10      9       15      26     False
# 2019-02-17     10       14      24     False
# 2019-02-24     16       11      24     False
# 2019-03-03     17       11      26     False
# 2019-03-10     17       14      25     False
# 2019-03-17     13       14      28     False
# 2019-03-24      8       13      29      True
#
# [261 rows x 4 columns]

# %%
pytrends.related_queries()
# Out:
# {'Tesla': {'top':                        query  value
#   0               tesla motors    100
#   1                tesla model     47
#   2              tesla model 3     27
#   3                    model 3     26
#   4              tesla model s     13
#   5                tesla apple     11
#   6              tesla model x     11
#   7                tesla stock     11
#   8                     spacex     10
#   9                    model x      9
#   10                tesla news      8
#   11                      musk      5
#   12                 elon musk      5
#   13           tesla elon musk      5
#   14                     solar      5
#   15               tesla solar      4
#   16                 tesla car      4
#   17                 new tesla      4
#   18               tesla price      3
#   19             tesla battery      3
#   20                tesla cars      3
#   21         tesla gigafactory      2
#   22           tesla autopilot      2
#   23               tesla truck      1
#   24  tesla model 3 production      1,
#   'rising':                        query   value
#   0              tesla model 3  823550
#   1                    model 3  784100
#   2          tesla gigafactory   70450
#   3            tesla autopilot   53700
#   4                tesla truck   40400
#   5   tesla model 3 production   39100
#   6           tesla production   38300
#   7            tesla powerwall   37000
#   8              tesla model y   33350
#   9         tesla announcement   24300
#   10                tesla semi   22000
#   11                chevy bolt   20650
#   12        tesla model 3 news   20450
#   13            faraday future   18300
#   14               tesla solar    1350
#   15                     solar     700
#   16                tesla cars     300
#   17             tesla model x     250
#   18                   model x     200
#   19                tesla news     200
#   20               tesla stock     160
#   21               tesla apple     150
#   22                 tesla car     140
#   23               tesla model     130
#   24                    spacex     130},
#  'Netflix': {'top':                   query  value
#   0           new netflix    100
#   1        netflix movies     92
#   2         netflix stock     63
#   3        netflix series     52
#   4         netflix shows     45
#   5         netflix apple     44
#   6     movies on netflix     41
#   7             daredevil     35
#   8     netflix daredevil     32
#   9          netflix news     29
#   10                 hulu     28
#   11    netflix streaming     27
#   12       netflix marvel     27
#   13       new on netflix     24
#   14      best on netflix     23
#   15     netflix releases     23
#   16         netflix down     22
#   17       disney netflix     21
#   18            the ranch     21
#   19        netflix price     19
#   20    the ranch netflix     17
#   21                  hbo     17
#   22      netflix comcast     15
#   23  netflix best movies     15
#   24         amazon prime     14,
#   'rising':                                      query   value
#   0                                daredevil  131900
#   1                        netflix daredevil  120000
#   2                                the ranch   78850
#   3                        the ranch netflix   65050
#   4                     the punisher netflix   48400
#   5                         punisher netflix   45600
#   6                        netflix iron fist   44600
#   7                        netflix september   41800
#   8                        luke cage netflix   37950
#   9                   chipotle mexican grill   33650
#   10                better call saul netflix   32700
#   11                   gilmore girls netflix   30750
#   12                      the office netflix   29650
#   13                           netflix anime   28150
#   14                  netflix september 2015   27800
#   15    series of unfortunate events netflix   27650
#   16                      marco polo netflix   27500
#   17                 nintendo switch netflix   26450
#   18                         witcher netflix   26400
#   19                          narcos netflix   24300
#   20                       the crown netflix   24300
#   21                       defenders netflix   24250
#   22                  dave chappelle netflix   24200
#   23  a series of unfortunate events netflix   21300
#   24                          netflix mexico   19550},
#  'Google': {'top':                   query  value
#   0           google news    100
#   1           maps google     31
#   2      google translate     26
#   3          google nexus     22
#   4        google android     15
#   5         google chrome     15
#   6         google search     15
#   7       facebook google     12
#   8           google play     11
#   9            google new     11
#   10         google fiber     10
#   11         google glass      9
#   12         google pixel      9
#   13       google finance      8
#   14         google drive      8
#   15       google scholar      7
#   16          google home      6
#   17         google earth      6
#   18          google apps      5
#   19     google classroom      4
#   20       google pixel 2      2
#   21          google allo      2
#   22  google logo history      1
#   23       google pixel 3      1
#   24      google alphabet      1, 'rising':                   query  value
#   0      google classroom  45650
#   1        google pixel 2  18200
#   2           google allo  18100
#   3   google logo history  13200
#   4        google pixel 3  12100
#   5       google alphabet  10750
#   6      google cardboard   8750
#   7       google pixel xl   8650
#   8          google pixel   8050
#   9          google inbox   7950
#   10   google pixel phone   6450
#   11    google terjemahan   6450
#   12           google duo   5300
#   13      google terjemah   5150
#   14        google sheets   3700
#   15      google daydream   3300
#   16     google translate    120
#   17         google fiber    110
#   18       google scholar    110
#   19          google news     80
#   20          google home     40}}

# %%
pytrends = TrendReq(hl='en-US', tz=360)
kw_list = ["Netflix", "Prime Video", "Roku", "Hulu", "HBO"]
pytrends.build_payload(kw_list, timeframe='today 5-y', geo='US', gprop='news')
Google_Trends_Media = pytrends.interest_over_time()
Google_Trends_Media
# Out:
#             Netflix  Prime Video  Roku  Hulu  HBO isPartial
# date
# 2014-03-30       14            0     2     3    5     False
# 2014-04-06       15            0     2     3   12     False
# 2014-04-13       15            0     2     2    6     False
# 2014-04-20       59            1     3     2   68     False
# 2014-04-27       23            1     1     4    5     False
# 2014-05-04       20            0     1     1    3     False
# 2014-05-11       17            0     2     3    4     False
# 2014-05-18       17            0     1     2    5     False
# 2014-05-25       12            0     1     4    8     False
# 2014-06-01       23            0     1     1    6     False
# 2014-06-08       34            0     1     2    4     False
# 2014-06-15       21            0     4     2    5     False
# 2014-06-22       12            0     2     1    3     False
# 2014-06-29       13            0     1     1    3     False
# 2014-07-06       15            0     2     3    4     False
# 2014-07-13       12            0     1     2    3     False
# 2014-07-20       15            1     1     2    3     False
# 2014-07-27       17            0     2     2    3     False
# 2014-08-03       16            0     2     1    3     False
# 2014-08-10       13            0     1     1    2     False
# 2014-08-17       12            0     4     1    3     False
# 2014-08-24       12            0     1     2    3     False
# 2014-08-31       19            0     1     2    2     False
# 2014-09-07       14            0     1     2    2     False
# 2014-09-14       16            0     2     1    4     False
# 2014-09-21       13            1     2     2    3     False
# 2014-09-28       25            0     1     1    1     False
# 2014-10-05       10            1     1     1    1     False
# 2014-10-12       31            0     2     2   54     False
# 2014-10-19       10            0     2     2    4     False
# ...             ...          ...   ...   ...  ...       ...
# 2018-09-02       24            1     3     5    4     False
# 2018-09-09       21            1     3     3    1     False
# 2018-09-16       21            1     2     4    4     False
# 2018-09-23       23            2     3    11    4     False
# 2018-09-30       23            0     1     4    2     False
# 2018-12-23      28      17          3      9        20     False
# 2018-12-30      23      13          2      9        23     False
# 2019-01-06      24      17          5      8        18     False
# 2019-01-13      22      15          4      7        18     False
# 2019-01-20      25      15          4      9        18     False
# 2019-01-27      24      14          6      8        21     False
# 2019-02-03      25      17          4      9        16     False
# 2019-02-10      26      39          3      9        17     False
# 2019-02-17      24      26          4      8        17     False
# 2019-02-24      24      20          3      8        22     False
# 2019-03-03      26      21          4     10        19     False
# 2019-03-10      25      17          3      7        35     False
# 2019-03-17      28      18          4      9        20     False
# 2019-03-24      29      14          4      8        17      True
#
# [261 rows x 6 columns]

# %%
#Stock Data 

from iexfinance.stocks import Stock
tsla = Stock('TSLA')
tsla.get_price()
# tsla.book()
# Out:
# 279.86

# %%
tsla.book()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-8e1a332b5776> in <module>
# ----> 1 tsla.book()
#
# AttributeError: 'Stock' object has no attribute 'book'

# %%
from datetime import datetime
from iexfinance.stocks import get_historical_data

start = datetime(2019, 3, 1)
end = datetime.today()

tsla_df = get_historical_data("TSLA", start, end, output_format='pandas')

# %%
tsla_df
# Out:
#               open      high       low   close    volume
# date
# 2019-03-01  306.94  307.1300  291.9000  294.79  22911375
# 2019-03-04  298.12  299.0000  282.7800  285.36  17096818
# 2019-03-05  282.00  284.0000  270.1000  276.54  18764740
# 2019-03-06  276.48  281.5058  274.3900  276.24  10335485
# 2019-03-07  278.84  284.7000  274.2500  276.59   9442483
# 2019-03-08  276.91  285.5900  275.8900  284.14   8819625
# 2019-03-11  283.52  291.2800  280.5000  290.92   7392278
# 2019-03-12  286.49  288.0700  281.0600  283.36   7504137
# 2019-03-13  283.90  291.9900  282.7000  288.96   6844719
# 2019-03-14  292.45  295.3900  288.2900  289.96   7103447
# 2019-03-15  283.51  283.7244  274.4000  275.43  14785531
# 2019-03-18  276.00  278.0500  267.3000  269.49  10280980
# 2019-03-19  267.50  273.3000  263.4600  267.47  11800630
# 2019-03-20  269.69  274.9700  266.3000  273.60   6908224
# 2019-03-21  272.60  276.4500  268.4500  274.02   5947098
# 2019-03-22  272.58  272.8000  264.0000  264.53   8745609
# 2019-03-25  259.71  263.1800  254.4600  260.42  10215029
# 2019-03-26  264.44  270.2600  264.4300  267.77   7350948
# 2019-03-27  268.75  275.3700  268.1838  274.83   8779166
# 2019-03-28  277.16  280.3300  275.1000  278.62   6774093
# 2019-03-29  278.70  280.1600  274.5000  279.86   5991338

# %%
googl = Stock('GOOGL')
googl.get_price()
start = datetime(2019, 3, 1)
end = datetime.today()

googl_df = get_historical_data("GOOGL", start, end, output_format='pandas')
googl_df
# Out:
#                open     high      low    close   volume
# date
# 2019-03-01  1131.00  1150.00  1131.00  1148.52  1704258
# 2019-03-04  1154.56  1165.52  1138.25  1153.42  1774467
# 2019-03-05  1156.00  1176.49  1153.02  1169.19  2004723
# 2019-03-06  1171.76  1174.74  1163.05  1164.94  1180052
# 2019-03-07  1160.50  1163.58  1141.71  1150.85  1504328
# 2019-03-08  1133.90  1153.45  1130.20  1149.97  1184732
# 2019-03-11  1152.00  1179.91  1151.57  1179.26  1501633
# 2019-03-12  1182.30  1205.71  1182.30  1197.25  2110979
# 2019-03-13  1205.93  1207.12  1197.91  1199.06  1294354
# 2019-03-14  1199.02  1204.70  1191.23  1192.53  1365072
# 2019-03-15  1198.00  1201.72  1187.01  1190.30  2593338
# 2019-03-18  1189.69  1194.95  1181.48  1188.55  1222203
# 2019-03-19  1191.72  1203.40  1189.46  1202.46  1489407
# 2019-03-20  1201.40  1229.99  1199.59  1226.43  2075442
# 2019-03-21  1220.00  1236.44  1216.58  1236.13  1407480
# 2019-03-22  1228.85  1233.63  1206.00  1207.65  1721133
# 2019-03-25  1199.56  1209.44  1190.00  1197.38  1378849
# 2019-03-26  1205.19  1207.65  1181.76  1189.84  1537606
# 2019-03-27  1191.92  1191.92  1164.23  1178.01  1471402
# 2019-03-28  1175.50  1177.25  1163.43  1172.27  1120122
# 2019-03-29  1180.18  1183.97  1166.38  1176.89  1544615

# %%
googl = Stock('GOOGL')
start = datetime(2019, 3, 1)
end = datetime.today()
googl_df = get_historical_data("GOOGL", start, end, output_format='pandas')
googl_df
# Out:
#                open     high      low    close   volume
# date
# 2019-03-01  1131.00  1150.00  1131.00  1148.52  1704258
# 2019-03-04  1154.56  1165.52  1138.25  1153.42  1774467
# 2019-03-05  1156.00  1176.49  1153.02  1169.19  2004723
# 2019-03-06  1171.76  1174.74  1163.05  1164.94  1180052
# 2019-03-07  1160.50  1163.58  1141.71  1150.85  1504328
# 2019-03-08  1133.90  1153.45  1130.20  1149.97  1184732
# 2019-03-11  1152.00  1179.91  1151.57  1179.26  1501633
# 2019-03-12  1182.30  1205.71  1182.30  1197.25  2110979
# 2019-03-13  1205.93  1207.12  1197.91  1199.06  1294354
# 2019-03-14  1199.02  1204.70  1191.23  1192.53  1365072
# 2019-03-15  1198.00  1201.72  1187.01  1190.30  2593338
# 2019-03-18  1189.69  1194.95  1181.48  1188.55  1222203
# 2019-03-19  1191.72  1203.40  1189.46  1202.46  1489407
# 2019-03-20  1201.40  1229.99  1199.59  1226.43  2075442
# 2019-03-21  1220.00  1236.44  1216.58  1236.13  1407480
# 2019-03-22  1228.85  1233.63  1206.00  1207.65  1721133
# 2019-03-25  1199.56  1209.44  1190.00  1197.38  1378849
# 2019-03-26  1205.19  1207.65  1181.76  1189.84  1537606
# 2019-03-27  1191.92  1191.92  1164.23  1178.01  1471402
# 2019-03-28  1175.50  1177.25  1163.43  1172.27  1120122
# 2019-03-29  1180.18  1183.97  1166.38  1176.89  1544615

# %%
nflx = Stock('NFLX')
nflx.get_price()
start = datetime(2019, 3, 1)
end = datetime.today()
nflx_df = get_historical_data("NFLX", start, end, output_format='pandas')
nflx_df
# Out:
#                open      high       low   close    volume
# date
# 2019-03-01  362.260  362.8700  354.6915  357.32   5526539
# 2019-03-04  359.720  362.2500  348.0436  351.04   7486996
# 2019-03-05  351.460  356.1700  348.2500  354.30   5937754
# 2019-03-06  353.600  359.8800  351.7000  359.61   6211895
# 2019-03-07  360.160  362.8600  350.5000  352.60   6151331
# 2019-03-08  345.750  349.9200  342.4700  349.60   6898838
# 2019-03-11  352.000  358.9800  350.0300  358.86   5387285
# 2019-03-12  359.370  360.1300  353.8000  356.27   5164571
# 2019-03-13  355.810  362.4800  352.7650  361.21   6444092
# 2019-03-14  360.500  363.8400  358.1008  358.82   5271429
# 2019-03-15  361.020  364.0000  358.8900  361.46   8443210
# 2019-03-18  362.470  370.9705  361.8600  363.44   7194726
# 2019-03-19  366.400  366.9600  356.8000  358.78   7541425
# 2019-03-20  358.910  375.9000  357.0100  375.22  10917165
# 2019-03-21  374.000  379.0000  370.6100  377.87   8544017
# 2019-03-22  375.950  376.4300  360.0400  361.01   8661346
# 2019-03-25  359.000  367.0399  357.4400  366.23   8473845
# 2019-03-26  367.870  368.3800  358.0200  359.97   7666475
# 2019-03-27  361.000  362.4700  350.3700  353.37   7852370
# 2019-03-28  354.485  355.9400  349.2000  354.61   4360960
# 2019-03-29  357.160  358.2500  353.7100  356.56   4705636

# %%
# TSLA Data for the past 6 months

# tsla_df = tsla.chart_table(range='6m')
# tsla_df.tail()

# %%
# Sort the data frame as most recent to match the order of tweets table

sort= tsla_df.sort_values("date", ascending = False)
sorted_tsla_df= sort.reset_index(drop= True)
sorted_tsla_df.tail()
# Out:
#       open      high     low   close    volume
# 16  278.84  284.7000  274.25  276.59   9442483
# 17  276.48  281.5058  274.39  276.24  10335485
# 18  282.00  284.0000  270.10  276.54  18764740
# 19  298.12  299.0000  282.78  285.36  17096818
# 20  306.94  307.1300  291.90  294.79  22911375

# %%
# Create dictionary for final dataframe by retrieving data from both the frames above

final_dict= {
            "Change($)" : sorted_tsla_df["change"],
            "Change Over Time(%)" :sorted_tsla_df["changeOverTime"],
            "Close" : sorted_tsla_df["close"],
            "Stock Volume":sorted_tsla_df["volume"],
            "Stock_Date" : sorted_tsla_df["date"],
            "Tweet": tweets_table["Tweet"],
            "Retweet" : tweets_table['Retweet'],
            "Compound Score":tweets_table["Compound Score"],
            "Tweet_Date": tweets_table["Date"],
            }

# create final dataframe

final_df = pd.DataFrame(final_dict)

# mapping some columns

final_df["Close"] = final_df["Close"].map("${:.2f}".format)
final_df["Change Over Time(%)"] = final_df["Change Over Time(%)"].map("{:.2f}%".format)

# Save the file to csv
final_df.to_csv('tweets_stockprice.csv')

# Display Head 
final_df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'change'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-5ef559b67254> in <module>
#       2
#       3 final_dict= {
# ----> 4             "Change($)" : sorted_tsla_df["change"],
#       5             "Change Over Time(%)" :sorted_tsla_df["changeOverTime"],
#       6             "Close" : sorted_tsla_df["close"],
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2686             return self._getitem_multilevel(key)
#    2687         else:
# -> 2688             return self._getitem_column(key)
#    2689
#    2690     def _getitem_column(self, key):
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2693         # get column
#    2694         if self.columns.is_unique:
# -> 2695             return self._get_item_cache(key)
#    2696
#    2697         # duplicate columns & possible reduce dimensionality
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    2487         res = cache.get(item)
#    2488         if res is None:
# -> 2489             values = self._data.get(item)
#    2490             res = self._box_item_values(item, values)
#    2491             cache[item] = res
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    4113
#    4114             if not isna(item):
# -> 4115                 loc = self.items.get_loc(item)
#    4116             else:
#    4117                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
# -> 3080                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    3081
#    3082         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'change'

# %%
# Visualzation of Positive v/s Negative Score of Tweets
plt.plot(tweets_table["Negative Score"],color="r")
plt.plot(tweets_table["Positive Score"],color="g")
plt.plot(final_df['Compound Score'], color="blue")

#Size of the figure
plt.rcParams["figure.figsize"] = [16,7]


plt.title("Compound v/s Positive v/s Negative Score (%s)" % (time.strftime("%m/%d/%Y")),fontweight='bold')
plt.ylabel("Range")
plt.xlabel("Number of Tweets")
plt.grid(True)
plt.legend(loc="best", fontsize="large", fancybox=True)

# Bold the line starting at 0
plt.axhline(y=0, color = 'black')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-58-6fda4c22bd03> in <module>
#       2 plt.plot(tweets_table["Negative Score"],color="r")
#       3 plt.plot(tweets_table["Positive Score"],color="g")
# ----> 4 plt.plot(final_df['Compound Score'], color="blue")
#       5
#       6 #Size of the figure
#
# NameError: name 'final_df' is not defined

# %%
# Compound Score Scaled to Millions to Compare Volume for plotting the data.

plt.plot(final_df["Compound Score"]*10000000,color="red")
plt.plot(sorted_tsla_df["volume"],color="black")

#Size of the figure
plt.rcParams["figure.figsize"] = [16,7]

plt.title("Volume v/s Compound Score in (Scaled Millions) (%s)" % (time.strftime("%m/%d/%Y")),fontweight='bold')
plt.ylabel("Range")
plt.xlabel("Number of trading days")
plt.grid(True)
plt.legend(loc="best", fontsize="large", fancybox=True)

# Bold the line starting at 0
plt.axhline(y=0, color = 'black')

# %%
# Compound Score Scaled to Hundereds to compare Closing Price of TSLA for plotting the data.

plt.plot(final_df["Compound Score"]*100,color="red")
plt.plot(sorted_tsla_df["close"],color="black")

#Size of the figure
plt.rcParams["figure.figsize"] = [16,7]

plt.title("Change in Closing Price (TSLA) v/s Compound Score in (Scaled Hundreds) (%s)" % (time.strftime("%m/%d/%Y")),fontweight='bold')
plt.ylabel("Range")
plt.xlabel("Number of trading days")
plt.grid(True)
plt.legend(loc="best", fontsize="large", fancybox=True)

# Bold the line starting at 0
plt.axhline(y=0, color = 'black')

# %%
# Compound Score Scaled to tens just to compare Change Over Time(%) for plotting the data.

plt.plot(tweets_table["Compound Score"]*10,color="red")
plt.plot(final_df["Change Over Time(%)"],color="b")

#Size of the figure
plt.rcParams["figure.figsize"] = [16,12]

plt.title("Change Over Time (TSLA)  v/s Compound Score of Tweets in (Tens) (%s)" % (time.strftime("%m/%d/%Y")),fontweight='bold')
plt.ylabel("Change Over Time(%)")
plt.xlabel("Compound Score in (Tens)")
plt.grid(True)
plt.legend(loc="best", fontsize="large", fancybox=True)

# Bold the line starting at 0
plt.axhline(y=0, color = 'black')

# %%
#Tweet Date vs Change Over Time(TSLA)(Visualize Stock Volatility Date wise)

plt.plot(final_df["Tweet_Date"],color="b")

#Size of the figure
plt.rcParams["figure.figsize"] = [16,15]

plt.ylabel("Change Over Time(%)")
plt.xlabel("Tweet Date")
plt.grid(True)
plt.legend(loc="best", fontsize="large", fancybox=True)

plt.plot(final_df["Change Over Time(%)"],color="r")

#Size of the figure
plt.rcParams["figure.figsize"] = [16,15]
plt.title("Tweet Date v/s Change Over Time (%s)" % (time.strftime("%m/%d/%Y")),fontweight='bold')
plt.ylabel("Change Over Time(%)                           Date Range")
plt.xlabel("Number of Trading Days")
plt.grid(True)
plt.legend(loc="best", fontsize="large", fancybox=True)

# Bold the line starting at 0
plt.axhline(y=0, color = 'black')

# %%
#No of Retweets compared to Compound score(Inverse Relationship)

plt.plot(final_df["Retweet"], "bo", linestyle="-", markersize=7, linewidth=1)
plt.plot(final_df["Compound Score"]*10000, "rs", linestyle="-", markersize=7, linewidth=1)

plt.title("Retweets v/s Compound Score  (%s)" % (time.strftime("%m/%d/%Y")),fontweight='bold')
plt.ylabel("Range (Scaled Thousands)")
plt.xlabel("Number of trading days")
plt.grid(True)
plt.legend(loc="best", fontsize="large", fancybox=True)

# Bold the line starting at 0
plt.axhline(y=0, color = 'black')

#Size of the figure
plt.rcParams["figure.figsize"] = [16,12]
