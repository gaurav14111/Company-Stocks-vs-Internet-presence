# %%
# Dependencies
import tweepy
import matplotlib.pyplot as plt
import pandas as pd
import json
import numpy as np
#import tim
import datetime
from iex import Stock

#import config 
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# %%
# Twitter API Keys
consumer_key = "N209m3gJ2swxPQR6dVN1QfhWZ"
consumer_secret = "habN4pBsGxJE0JZGZIaOpSiXgUZfQkFc6TfocJGB7vyFb03GQ0"
access_token = "189069676-Plx8vrhvcScSVYwvvbmijehJnACqdow4qkVccL4V"
access_token_secret = "w60yWFtVOtJ3G31slMlbPVRO9mzsDYUjlUE4G3QUQFZqc"

# Twitter credentials
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())

# %%
# Create columns for dataframe
tweets_table = {
                'Tweet Number': '',
                'PersonTweeted': '',
                'Tweet': '',
                'Compound Score': '',
                'Positive Score': '',
                'Negative Score': '',
                'Neutral Score': ''}

# %%
# Create list of news accounts
target_terms = ['@mtbarra', '@sundarpichai', '@reedhastings']

# %%
# Variable to hold list of the compound sentiment
compound_list = []
positive_list = []
negative_list = []
neutral_list = []
tweet_number = []
person_tweeted = []
text = []
created =[]
retweet = []
likes = [] 

# 'retweeted_status': {'created_at': 'Thu Mar 28 19:02:10 +0000 2019',
#    'id': 1111342735066365952,
#    'id_str': '1111342735066365952',
#    'text': 'CEO Spotlight: @SteveForbesCEO, Chairman @Forbes joins @NPetallides live from the @Nasdaq Market Site.',
      
# Loop through all target users
for target in target_terms:
        
    # Run search around each tweet(Upto max of 200 tweets at once)
    screen_name = target
    public_tweets = api.user_timeline(target, count=200,result_type ="recent")

    
    # Index to see how many tweets for each news source
    index = 0
        
    # Loop through all tweets
    
    for tweet in public_tweets:
        
        news_organization = target
            
        # Run vader analysis on each tweet
        
        scores = analyzer.polarity_scores(tweet['text'])
        compound = scores['compound']
        pos = scores['pos']
        neu = scores['neu']
        neg = scores['neg']
            
        # Append values to empty lists
        
        compound_list.append(compound)
        positive_list.append(pos)
        negative_list.append(neg)
        neutral_list.append(neu)
        text.append(tweet['text'])
        tweet_number.append(index)
        person_tweeted.append(target)
        tweet_date = datetime.datetime.strptime(tweet["created_at"], "%a %b %d %H:%M:%S %z %Y")
        convert_time = datetime.datetime.strftime(tweet_date, '%y-%m-%d')
        created.append(convert_time)
        retweet.append(tweet["retweet_count"])
        likes.append(tweet["favorite_count"])      
        index = index + 1

# %%
len(tweet_number)
# Out:
# 487

# %%
len(public_tweets)
# Out:
# 87

# %%
#Create dataframe from the lists appended above 

tweets_table = {
                'Person_Tweeted' : person_tweeted,
                'Tweet Number' : tweet_number,
                'Tweet' : text,
                'Compound Score' : compound_list,
                'Positive Score': positive_list,
                'Negative Score': negative_list,
                'Date': created,
                'Retweet' : retweet,
                'Likes' : likes
                
}

tweets_table = pd.DataFrame(tweets_table)

# %%
tweets_table
# Out:
#     Person_Tweeted  Tweet Number  \
# 0         @mtbarra             0
# 1         @mtbarra             1
# 2         @mtbarra             2
# 3         @mtbarra             3
# 4         @mtbarra             4
# 5         @mtbarra             5
# 6         @mtbarra             6
# 7         @mtbarra             7
# 8         @mtbarra             8
# 9         @mtbarra             9
# 10        @mtbarra            10
# 11        @mtbarra            11
# 12        @mtbarra            12
# 13        @mtbarra            13
# 14        @mtbarra            14
# 15        @mtbarra            15
# 16        @mtbarra            16
# 17        @mtbarra            17
# 18        @mtbarra            18
# 19        @mtbarra            19
# 20        @mtbarra            20
# 21        @mtbarra            21
# 22        @mtbarra            22
# 23        @mtbarra            23
# 24        @mtbarra            24
# 25        @mtbarra            25
# 26        @mtbarra            26
# 27        @mtbarra            27
# 28        @mtbarra            28
# 29        @mtbarra            29
# ..             ...           ...
# 457  @reedhastings            57
# 458  @reedhastings            58
# 459  @reedhastings            59
# 460  @reedhastings            60
# 461  @reedhastings            61
# 462  @reedhastings            62
# 463  @reedhastings            63
# 464  @reedhastings            64
# 465  @reedhastings            65
# 466  @reedhastings            66
# 467  @reedhastings            67
# 468  @reedhastings            68
# 469  @reedhastings            69
# 470  @reedhastings            70
# 471  @reedhastings            71
# 472  @reedhastings            72
# 473  @reedhastings            73
# 474  @reedhastings            74
# 475  @reedhastings            75
# 476  @reedhastings            76
# 477  @reedhastings            77
# 478  @reedhastings            78
# 479  @reedhastings            79
# 480  @reedhastings            80
# 481  @reedhastings            81
# 482  @reedhastings            82
# 483  @reedhastings            83
# 484  @reedhastings            84
# 485  @reedhastings            85
# 486  @reedhastings            86
#
#                                                  Tweet  Compound Score  \
# 0    Excited to bring these jobs and investment to ...          0.6124
# 1    Equal pay is not only a moral issue but a busi...          0.8100
# 2    And while it’s hard to say goodbye to colleagu...          0.5859
# 3    I want to thank Alan Batey for his 40 years of...          0.8689
# 4    The work our engineers do every day - solving ...          0.4767
# 5    As we continue to transform how @GM operates, ...          0.7096
# 6    Keeping @RepDebDingell and her family in our t...         -0.1027
# 7    2018 was an important year for @GM. We navigat...          0.3818
# 8    Like every business, we must earn the right to...          0.7906
# 9    I’m excited to announce that Mark Reuss, head ...          0.3400
# 10   …Today, we have a plan for the majority of emp...          0.0000
# 11   I understand how GM’s recent news is affecting...          0.2960
# 12   We will miss this great man, President George ...          0.6457
# 13   Our third-quarter performance demonstrates our...          0.5994
# 14   Looking forward to speaking with @TheAtlantic’...          0.2500
# 15   What happened in Pittsburgh is both tragic and...          0.0258
# 16   Today, and every day, I raise my hand with my ...          0.7096
# 17   I’d like to welcome Jami Miscik, CEO of Kissin...          0.6705
# 18   Human error causes 94% of the nearly 40,000 de...         -0.5719
# 19   As an open, inclusive company, we work hard to...          0.7184
# 20   RT @GM: We’re proud to announce another step t...          0.6249
# 21   Proud to support our commitment to @AmericanCa...         -0.0516
# 22   Congratulations to my colleague Dhivya on this...          0.8070
# 23   Challenge accepted, @JPMorganChase and @BizRou...          0.3400
# 24   Thanks Dan, it was fun! Impressive, informed q...          0.9314
# 25   @MrsAdrienneBosh @GM @axios @GirlsWhoCode @cod...          0.6249
# 26   In 2017, we set a bold goal for the industry, ...          0.3818
# 27   RT @axios: Axios is headed to Boston on Friday...          0.4389
# 28   Sen. John McCain was a patriot and committed p...          0.6486
# 29   Thank you, Aretha, for the inspiration and pri...          0.8074
# ..                                                 ...             ...
# 457  https://t.co/hQRFeQjn8r\n\nT-Mobile goes uncar...          0.0000
# 458  RT @ShaliniWSJ: Gotta give a shoutout to Netfl...          0.6249
# 459  RT @ShaliniWSJ: Want 10 gigabit-per-second Int...          0.0772
# 460  RT @decider: Cary Fukunaga is this generation’...          0.0000
# 461  "JetBlue will have free satellite WiFi on ever...          0.5106
# 462  Netflix and chill condoms?  The meme has got t...          0.0000
# 463  Connected flights: The unstoppable rise of in-...         -0.2023
# 464  RT @sapinker: Taxis are cartels wh exploit dri...         -0.3935
# 465  Congrats @HBO on supporting so much Emmy-winni...          0.9457
# 466  RT @WernerTwertzog: Man is born free, but ever...          0.2846
# 467  RT @ItCanWait: No post, glance or email is wor...         -0.0772
# 468  RT @decider: We saw @Netflix's #BeastsOfNoNati...          0.2500
# 469              @pmarca That's about one per retweet.          0.0000
# 470  RT @WSJ: Mark Zuckerberg and his wife Priscill...          0.0000
# 471  RT @cdixon: "We need to rethink our strategy o...          0.4215
# 472  RT @ditzkoff: Inside look at the HBO and Netfl...          0.0000
# 473  RT @netflix: Netflix members watched 10 billio...          0.0000
# 474  RT @bdsams: Microsoft updates Windows Defender...          0.4404
# 475  one of my favorite economists on bitcoin. \nht...          0.4588
# 476  Turing's persecution fuels us to stand up for ...         -0.0516
# 477  RT @mjones: A phone that I don't use to make c...          0.0000
# 478  RT @tpf: Bill smiling at Courmayeur after a to...          0.8020
# 479  RT @ruzwana: The most important article I've e...          0.6115
# 480  RT @BoJackHorseman: Straight from &amp; into t...          0.3578
# 481  RT @netflix: I thought we had a deal. #Houseof...          0.0000
# 482  RT @jshmoobie: @lisadraws art in BoJack Horsem...          0.8957
# 483  RT @Michael_Eisner: Thank u @usatoday         ...          0.3612
# 484  RT @HuffingtonPost: It just got harder to turn...          0.0000
# 485  RT @pkafka: Insane that earnings calls still s...         -0.4019
# 486  @fakerholic Indie band in the desert sounds mo...          0.5563
#
#      Positive Score  Negative Score      Date  Retweet  Likes
# 0             0.200           0.000  19-03-22       64    294
# 1             0.345           0.048  19-03-08       49    212
# 2             0.195           0.053  19-02-28        9     85
# 3             0.383           0.000  19-02-28       25    181
# 4             0.186           0.000  19-02-20       14    109
# 5             0.228           0.000  19-02-11       19    143
# 6             0.000           0.065  19-02-08       35    279
# 7             0.175           0.000  19-02-06       32    123
# 8             0.292           0.049  19-01-29       82    343
# 9             0.103           0.000  19-01-03       92    477
# 10            0.000           0.000  18-12-14       34    204
# 11            0.115           0.000  18-12-14       40    182
# 12            0.208           0.068  18-12-01       56    420
# 13            0.284           0.100  18-10-31       56    216
# 14            0.105           0.000  18-10-29       16     84
# 15            0.129           0.124  18-10-28       64    324
# 16            0.237           0.000  18-10-11      140    560
# 17            0.234           0.000  18-10-10       17     95
# 18            0.000           0.207  18-10-08       65    173
# 19            0.287           0.054  18-10-04       56    238
# 20            0.203           0.000  18-10-03       88      0
# 21            0.290           0.297  18-10-03       73    138
# 22            0.288           0.000  18-09-25       74    337
# 23            0.185           0.000  18-09-21       47    189
# 24            0.450           0.000  18-09-12        6     50
# 25            0.227           0.000  18-09-07        2     18
# 26            0.110           0.000  18-09-05       96    346
# 27            0.121           0.000  18-09-04       14      0
# 28            0.249           0.000  18-09-01       47    295
# 29            0.328           0.000  18-08-31       97    362
# ..              ...             ...       ...      ...    ...
# 457           0.000           0.000  15-11-10       18     31
# 458           0.186           0.000  15-11-09        6      0
# 459           0.064           0.000  15-10-16        6      0
# 460           0.000           0.000  15-10-16        4      0
# 461           0.216           0.000  15-10-15      170    262
# 462           0.000           0.000  15-10-08       57    103
# 463           0.000           0.153  15-10-04       33     68
# 464           0.000           0.161  15-09-30      404      0
# 465           0.619           0.000  15-09-21       31     74
# 466           0.152           0.000  15-09-20     1132      0
# 467           0.068           0.078  15-09-19     5806      0
# 468           0.100           0.000  15-09-19        8      0
# 469           0.000           0.000  15-09-12        0     12
# 470           0.000           0.000  15-06-18      272      0
# 471           0.149           0.000  15-06-16     2553      0
# 472           0.000           0.000  15-04-09      115      0
# 473           0.000           0.000  15-04-08      822      0
# 474           0.206           0.000  15-02-20      198      0
# 475           0.300           0.000  15-02-09       12     37
# 476           0.099           0.107  15-01-01       49     97
# 477           0.000           0.000  14-09-10      645      0
# 478           0.360           0.062  14-08-30        1      0
# 479           0.277           0.000  14-08-30     1699      0
# 480           0.121           0.000  14-08-27      677      0
# 481           0.000           0.000  14-08-26      191      0
# 482           0.405           0.074  14-08-25        1      0
# 483           0.385           0.000  14-08-24        5      0
# 484           0.000           0.000  14-08-24       27      0
# 485           0.000           0.114  14-08-06       20      0
# 486           0.310           0.000  14-06-02        2      3
#
# [487 rows x 9 columns]

# %%
len(tweets_table["Date"])

# %%
# Drop rows from the end rows to match the array index for merging

tweets_table.drop(tweets_table.index[128:200],inplace=True)

tweets_table.tail()

# %%
#Stock Data 

# tsla = Stock("TSLA")
# tsla.book()

# %%
# TSLA Data for the past 6 months

# tsla_df = tsla.chart_table(range='6m')
# tsla_df.tail()

# %%
# Sort the data frame as most recent to match the order of tweets table

sort= tsla_df.sort_values("date", ascending = False)
sorted_tsla_df= sort.reset_index(drop= True)
sorted_tsla_df.tail()

# %%
# Create dictionary for final dataframe by retrieving data from both the frames above

final_dict= {"Change($)" : sorted_tsla_df["change"],
             "Change Over Time(%)" :sorted_tsla_df["changeOverTime"],
            "Close" : sorted_tsla_df["close"],
            "Stock Volume":sorted_tsla_df["volume"],
            "Stock_Date" : sorted_tsla_df["date"],
            "Tweet": tweets_table["Tweet"],
             "Retweet" : tweets_table['Retweet'],
            "Compound Score":tweets_table["Compound Score"],
            "Tweet_Date": tweets_table["Date"],
            }

# create final dataframe

final_df = pd.DataFrame(final_dict)

# mapping some columns

final_df["Close"] = final_df["Close"].map("${:.2f}".format)
final_df["Change Over Time(%)"] = final_df["Change Over Time(%)"].map("{:.2f}%".format)

# Save the file to csv
final_df.to_csv('tweets_stockprice.csv')

# Display Head 
final_df.head()

# %%
# Visualzation of Positive v/s Negative Score of Tweets
plt.plot(tweets_table["Negative Score"],color="r")
plt.plot(tweets_table["Positive Score"],color="g")
plt.plot(final_df['Compound Score'], color="blue")

#Size of the figure
plt.rcParams["figure.figsize"] = [16,7]


plt.title("Compound v/s Positive v/s Negative Score (%s)" % (time.strftime("%m/%d/%Y")),fontweight='bold')
plt.ylabel("Range")
plt.xlabel("Number of Tweets")
plt.grid(True)
plt.legend(loc="best", fontsize="large", fancybox=True)

# Bold the line starting at 0
plt.axhline(y=0, color = 'black')

# %%
# Compound Score Scaled to Millions to Compare Volume for plotting the data.

plt.plot(final_df["Compound Score"]*10000000,color="red")
plt.plot(sorted_tsla_df["volume"],color="black")

#Size of the figure
plt.rcParams["figure.figsize"] = [16,7]

plt.title("Volume v/s Compound Score in (Scaled Millions) (%s)" % (time.strftime("%m/%d/%Y")),fontweight='bold')
plt.ylabel("Range")
plt.xlabel("Number of trading days")
plt.grid(True)
plt.legend(loc="best", fontsize="large", fancybox=True)

# Bold the line starting at 0
plt.axhline(y=0, color = 'black')

# %%
# Compound Score Scaled to Hundereds to compare Closing Price of TSLA for plotting the data.

plt.plot(final_df["Compound Score"]*100,color="red")
plt.plot(sorted_tsla_df["close"],color="black")

#Size of the figure
plt.rcParams["figure.figsize"] = [16,7]

plt.title("Change in Closing Price (TSLA) v/s Compound Score in (Scaled Hundreds) (%s)" % (time.strftime("%m/%d/%Y")),fontweight='bold')
plt.ylabel("Range")
plt.xlabel("Number of trading days")
plt.grid(True)
plt.legend(loc="best", fontsize="large", fancybox=True)

# Bold the line starting at 0
plt.axhline(y=0, color = 'black')

# %%
# Compound Score Scaled to tens just to compare Change Over Time(%) for plotting the data.

plt.plot(tweets_table["Compound Score"]*10,color="red")
plt.plot(final_df["Change Over Time(%)"],color="b")

#Size of the figure
plt.rcParams["figure.figsize"] = [16,12]

plt.title("Change Over Time (TSLA)  v/s Compound Score of Tweets in (Tens) (%s)" % (time.strftime("%m/%d/%Y")),fontweight='bold')
plt.ylabel("Change Over Time(%)")
plt.xlabel("Compound Score in (Tens)")
plt.grid(True)
plt.legend(loc="best", fontsize="large", fancybox=True)

# Bold the line starting at 0
plt.axhline(y=0, color = 'black')

# %%
#Tweet Date vs Change Over Time(TSLA)(Visualize Stock Volatility Date wise)

plt.plot(final_df["Tweet_Date"],color="b")

#Size of the figure
plt.rcParams["figure.figsize"] = [16,15]

plt.ylabel("Change Over Time(%)")
plt.xlabel("Tweet Date")
plt.grid(True)
plt.legend(loc="best", fontsize="large", fancybox=True)

plt.plot(final_df["Change Over Time(%)"],color="r")

#Size of the figure
plt.rcParams["figure.figsize"] = [16,15]
plt.title("Tweet Date v/s Change Over Time (%s)" % (time.strftime("%m/%d/%Y")),fontweight='bold')
plt.ylabel("Change Over Time(%)                           Date Range")
plt.xlabel("Number of Trading Days")
plt.grid(True)
plt.legend(loc="best", fontsize="large", fancybox=True)

# Bold the line starting at 0
plt.axhline(y=0, color = 'black')

# %%
#No of Retweets compared to Compound score(Inverse Relationship)

plt.plot(final_df["Retweet"], "bo", linestyle="-", markersize=7, linewidth=1)
plt.plot(final_df["Compound Score"]*10000, "rs", linestyle="-", markersize=7, linewidth=1)

plt.title("Retweets v/s Compound Score  (%s)" % (time.strftime("%m/%d/%Y")),fontweight='bold')
plt.ylabel("Range (Scaled Thousands)")
plt.xlabel("Number of trading days")
plt.grid(True)
plt.legend(loc="best", fontsize="large", fancybox=True)

# Bold the line starting at 0
plt.axhline(y=0, color = 'black')

#Size of the figure
plt.rcParams["figure.figsize"] = [16,12]
