# %% [markdown]
# # Project "The relationship between companies' stock prices and their internet presence"

# %% [markdown]
# ## Stock prices

# %%
#Data retrieving

#Dependencies
from iexfinance.stocks import get_historical_data # Python module to get stock data from IEX Cloud and IEX API 1.0 (https://pypi.org/project/iexfinance/)
from datetime import datetime
import pandas as pd

# %%
start = str(datetime.today().year - 1)+"-"+str(datetime.today().month)+"-"+str(datetime.today().day + 1) 
#datetime(2019, 3, 1)
end = datetime.today()

company_stock_symbols = ["TSLA", "GOOGL", "NFLX"]
company_names = ["Tesla, Inc.", "Google LLC", "Netflix, Inc."]

stock_df = pd.DataFrame()

for item in range(len(company_stock_symbols)):
    temp_df = get_historical_data(str(company_stock_symbols[item]), start, end, output_format='pandas')
    temp_df ["Company Name"] = str(company_names[item])
    stock_df = stock_df.append(temp_df, sort=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-72204876896c> in <module>()
#      11     temp_df = get_historical_data(str(company_stock_symbols[item]), start, end, output_format='pandas')
#      12     temp_df ["Company Name"] = str(company_names[item])
# ---> 13     stock_df = stock_df.append(temp_df, sort=False)
#      14
#
# TypeError: append() got an unexpected keyword argument 'sort'

# %%
stock_df.reset_index(level=0, inplace=True)
stock_df
# Out:
#           date      open      high       low    close    volume   Company Name
# 0   2018-04-03  269.8200  273.3500  254.4900  267.530  18844384    Tesla, Inc.
# 1   2018-04-04  252.7800  288.3700  252.0000  286.940  19896746    Tesla, Inc.
# 2   2018-04-05  289.3400  306.2600  288.2000  305.720  19121101    Tesla, Inc.
# 3   2018-04-06  301.0000  309.2800  295.5000  299.300  13520286    Tesla, Inc.
# 4   2018-04-09  300.3700  309.5000  289.2100  289.660  10249805    Tesla, Inc.
# 5   2018-04-10  298.9700  307.1000  293.6800  304.700  11024259    Tesla, Inc.
# 6   2018-04-11  300.7403  308.9800  299.6600  300.930   7482945    Tesla, Inc.
# 7   2018-04-12  302.3200  303.9500  293.6800  294.080   7608769    Tesla, Inc.
# 8   2018-04-13  303.6000  303.9499  295.9800  300.340   7327223    Tesla, Inc.
# 9   2018-04-16  299.0000  299.6600  289.0100  291.210   6338488    Tesla, Inc.
# 10  2018-04-17  288.8700  292.1700  282.5100  287.690   7000023    Tesla, Inc.
# 11  2018-04-18  291.0800  300.2400  288.1600  293.350   6557700    Tesla, Inc.
# 12  2018-04-19  291.0800  301.0100  288.5500  300.080   6090599    Tesla, Inc.
# 13  2018-04-20  295.1700  299.9800  289.7500  290.240   5627928    Tesla, Inc.
# 14  2018-04-23  291.2900  291.6200  282.3300  283.370   4893378    Tesla, Inc.
# 15  2018-04-24  285.0000  287.0900  278.4600  283.460   5685308    Tesla, Inc.
# 16  2018-04-25  283.5000  285.1600  277.2500  280.690   4013574    Tesla, Inc.
# 17  2018-04-26  278.7500  285.7900  276.5000  285.480   4356013    Tesla, Inc.
# 18  2018-04-27  285.3700  294.4700  283.8300  294.075   4364626    Tesla, Inc.
# 19  2018-04-30  293.6100  298.7300  292.5000  293.900   4228172    Tesla, Inc.
# 20  2018-05-01  293.5100  300.8200  293.2200  299.920   4625603    Tesla, Inc.
# 749 2019-03-27  361.0000  362.4700  350.3700  353.370   7852370  Netflix, Inc.
# 750 2019-03-28  354.4850  355.9400  349.2000  354.610   4360960  Netflix, Inc.
# 751 2019-03-29  357.1600  358.2500  353.7100  356.560   4705636  Netflix, Inc.
# 752 2019-04-01  359.0000  368.3300  358.5100  366.960   7036097  Netflix, Inc.
#
# [753 rows x 7 columns]

# %%
#Save to csv file
stock_path = "C:/Users/Anna/Documents/Berkeley Data Analytics Boot Camp/Project 1"
stock_df.to_csv("Stock_data.csv", index=False)

# %% [markdown]
# ## Internet presence indicators

# %% [markdown]
# ### Google trends

# %%
#Dependencies
from pytrends.request import TrendReq # Pseudo API for Google Trends (https://pypi.org/project/pytrends/)

# %%
# Get the ratings from Google Trends
pytrends = TrendReq(hl='en-US', tz=360)
queries_list = ["Tesla", "Netflix", "Google"]
pytrends.build_payload(queries_list, timeframe='today 3-m', geo='US', gprop='news')
google_trends_df = pytrends.interest_over_time()

# %%
google_trends_df.reset_index(level=0, inplace=True)
google_trends_df
# Out:
#          date  Tesla  Netflix  Google  isPartial
# 0  2019-01-02     35       23      38      False
# 1  2019-01-03     15       26      41      False
# 2  2019-01-04     11       30      80      False
# 3  2019-01-05     10       39      34      False
# 4  2019-01-06     27       27      45      False
# 5  2019-01-07     17       21      49      False
# 6  2019-01-08     10       24      49      False
# 7  2019-01-09     21       24      59      False
# 8  2019-01-10     25       39      46      False
# 9  2019-01-11     11       29      57      False
# 10 2019-01-12     23       59      86      False
# 11 2019-01-13     13       35      39      False
# 12 2019-01-14     17       21      58      False
# 13 2019-01-15     41       48      52      False
# 14 2019-01-16     29       36      54      False
# 15 2019-01-17     31       51      55      False
# 16 2019-01-18     25       54      36      False
# 17 2019-01-19     18       40      53      False
# 18 2019-01-20     35       35      78      False
# 19 2019-01-21      8       50      50      False
# 20 2019-01-22     32       42      74      False
# 21 2019-01-23     24       37      71      False
# 22 2019-01-24     27       34      48      False
# 23 2019-01-25     20       37      55      False
# 24 2019-01-26     37       42      51      False
# 25 2019-01-27     14       42      56      False
# 26 2019-01-28     35       38      45      False
# 27 2019-01-29     27       33      60      False
# 28 2019-01-30     33       23      53      False
# 29 2019-01-31     48       17      51      False
# ..        ...    ...      ...     ...        ...
# 57 2019-02-28     55       27      83      False
# 58 2019-03-01     50       21      50      False
# 59 2019-03-02     51       28      28      False
# 60 2019-03-03     51       23      55      False
# 61 2019-03-04     45       21      75      False
# 62 2019-03-05     38       34      41      False
# 63 2019-03-06     47        4      43      False
# 64 2019-03-07     49       30      34      False
# 65 2019-03-08     35       20      70      False
# 66 2019-03-09     20       39      44      False
# 67 2019-03-10     42       51      70      False
# 68 2019-03-11     42       24      59      False
# 69 2019-03-12     43       23      56      False
# 70 2019-03-13     28       22      35      False
# 71 2019-03-14     51       17      65      False
# 72 2019-03-15     81       28      56      False
# 73 2019-03-16      9       33      52      False
# 74 2019-03-17     28       47      47      False
# 75 2019-03-18     37       37      48      False
# 76 2019-03-19     36       14     100      False
# 77 2019-03-20     33       26      66      False
# 78 2019-03-21     32       18      85      False
# 79 2019-03-22      7       22      41      False
# 80 2019-03-23     29       48      63      False
# 81 2019-03-24      9       42      55      False
# 82 2019-03-25     29       40      62      False
# 83 2019-03-26     11       30      48      False
# 84 2019-03-27     30        7      79      False
# 85 2019-03-28      4       15      42      False
# 86 2019-03-29     36        8      49      False
#
# [87 rows x 5 columns]

# %%
#Save to csv file
google_trends_df.to_csv("Google_trends_data.csv", index=False)

# %% [markdown]
# ### Twitter sentiment analysis results

# %%
# Dependencies
import tweepy
import pandas as pd
import json
import numpy as np
import datetime
import regex as re
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# Twitter API Keys
consumer_key = "N209m3gJ2swxPQR6dVN1QfhWZ"
consumer_secret = "habN4pBsGxJE0JZGZIaOpSiXgUZfQkFc6TfocJGB7vyFb03GQ0"
access_token = "189069676-Plx8vrhvcScSVYwvvbmijehJnACqdow4qkVccL4V"
access_token_secret = "w60yWFtVOtJ3G31slMlbPVRO9mzsDYUjlUE4G3QUQFZqc"

# Twitter credentials
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())

# Create columns for dataframe
tweets_table = {
                'Tweet Number': '',
                'PersonTweeted': '',
                'Tweet': '',
                'Compound Score': '',
                'Positive Score': '',
                'Negative Score': '',
                'Neutral Score': ''}

# Create list of news accounts
target_terms = ['@elonmusk', '@sundarpichai', '@reedhastings']

# Variable to hold list of the compound sentiment
compound_list = []
positive_list = []
negative_list = []
neutral_list = []
tweet_number = []
person_tweeted = []
text = []
created =[]
retweet = []
likes = [] 

# Loop through all target users
for target in target_terms:
        
    # Run search around each tweet(Upto max of 200 tweets at once)
    screen_name = target
    public_tweets = api.user_timeline(target, count=200,result_type ="recent")
    
    # Index to see how many tweets for each news source
    index = 0
        
    # Loop through all tweets    
    for tweet in public_tweets:
        
        news_organization = target
            
        # Run vader analysis on each tweet
        xxx = tweet['text']
        result = re.sub('RT @([A-Za-z0-9_]+\:) ', '', xxx)
        tweet['text'] = result
        scores = analyzer.polarity_scores(tweet['text'])
        compound = scores['compound']
        pos = scores['pos']
        neu = scores['neu']
        neg = scores['neg']
            
        # Append values to empty lists        
        compound_list.append(compound)
        positive_list.append(pos)
        negative_list.append(neg)
        neutral_list.append(neu)
        text.append(tweet['text'])
        tweet_number.append(index)
        person_tweeted.append(target)
        tweet_date = datetime.datetime.strptime(tweet["created_at"], "%a %b %d %H:%M:%S %z %Y")
        convert_time = datetime.datetime.strftime(tweet_date, '%y-%m-%d')
        created.append(convert_time)
        retweet.append(tweet["retweet_count"])
        likes.append(tweet["favorite_count"])      
        
        index = index + 1
        
#Create dataframe from the lists appended above 
tweets_table = {
                'Person_Tweeted' : person_tweeted,
                'Tweet Number' : tweet_number,
                'Tweet' : text,
                'Compound Score' : compound_list,
                'Positive Score': positive_list,
                'Negative Score': negative_list,
                'Neutral Score': neutral_list,    
                'Date': created,
                'Retweet' : retweet,
                'Likes' : likes}

tweets_df = pd.DataFrame(tweets_table)
tweets_df
# Out:
#      Compound Score      Date   Likes  Negative Score  Neutral Score  \
# 0            0.8591  19-04-04     156           0.000          0.558
# 1            0.6249  19-04-04     818           0.000          0.549
# 2            0.0000  19-04-04     413           0.000          1.000
# 18                                     @dogecoin Uh oh            18
# 19   @Tom_Heats Dogecoin might be my fav cryptocurr...            19
# 20                         Yup https://t.co/UpMKB24yNB            20
# 21   @klod_ua @universal_sci Some challenges with i...            21
# 22        @universal_sci What could possibly go wrong?            22
# 23                                  @TrevMcKendrick No            23
# 24      @Iron_Mechanic You’re so right. Working on it!            24
# 25   @VHollywood21 That car seemed so advanced when...            25
# 26   @maxwellk_ @Teslarati And even tinier ones for...            26
# 27                         @maxwellk_ @Teslarati Yes 🐜            27
# 28   @Teslarati Going forward, all Tesla stores wil...            28
# 29   @jgrano305 @ProjectVayo @keen_lab Meant to say...            29
# ..                                                 ...           ...
# 457  https://t.co/hQRFeQjn8r\n\nT-Mobile goes uncar...            57
# 458  Gotta give a shoutout to Netflix's #MasterOfNo...            58
# 459  Want 10 gigabit-per-second Internet service to...            59
# 460  Cary Fukunaga is this generation’s genre-defyi...            60
# 461  "JetBlue will have free satellite WiFi on ever...            61
# 462  Netflix and chill condoms?  The meme has got t...            62
# 463  Connected flights: The unstoppable rise of in-...            63
# 464  Taxis are cartels wh exploit drivers &amp; rid...            64
# 465  Congrats @HBO on supporting so much Emmy-winni...            65
# 466  Man is born free, but everywhere he is checkin...            66
# 467  No post, glance or email is worth a life. RT t...            67
# 468  We saw @Netflix's #BeastsOfNoNation at #TIFF15...            68
# 469              @pmarca That's about one per retweet.            69
# 470  Mark Zuckerberg and his wife Priscilla Chan do...            70
# 471  "We need to rethink our strategy of hoping the...            71
# 472  Inside look at the HBO and Netflix PR departme...            72
# 473  Netflix members watched 10 billion hours last ...            73
# 474  Microsoft updates Windows Defender, fries Supe...            74
# 475  one of my favorite economists on bitcoin. \nht...            75
# 476  Turing's persecution fuels us to stand up for ...            76
# 477  A phone that I don't use to make calls now pai...            77
# 478  Bill smiling at Courmayeur after a tough, cold...            78
# 479  The most important article I've ever written. ...            79
# 480  Straight from &amp; into the horse's mouth! #B...            80
# 481  I thought we had a deal. #HouseofCards #Emmys ...            81
# 482  @lisadraws art in BoJack Horseman is crazy awe...            82
# 483  Thank u @usatoday                http://t.co/u...            83
# 484  It just got harder to turn off Netflix http://...            84
# 485  Insane that earnings calls still start w/15-30...            85
# 486  @fakerholic Indie band in the desert sounds mo...            86
#
# [487 rows x 10 columns]

# %%
#Data aggregation in order to figure out the total characteristics on the daily impacts of tweets by person
grouped_tweets_data = tweets_df.groupby(["Date"])
tweets_data_summary = pd.DataFrame({"Twitter Account": grouped_tweets_data["Person_Tweeted"].unique().str.get(0), 
                                    "Total Tweets": grouped_tweets_data["Tweet"].count(),
                                    "Average Compound Score": grouped_tweets_data["Compound Score"].mean(),
                                    "Average Positive Score": grouped_tweets_data["Positive Score"].mean(),
                                    "Average Negative Score": grouped_tweets_data["Negative Score"].mean(),
                                    "Average Neutral Score": grouped_tweets_data["Neutral Score"].mean(),
                                    "Total Retweets": grouped_tweets_data["Retweet"].sum(),
                                    "Total Likes": grouped_tweets_data["Likes"].sum()})
tweets_data_summary
# Out:
#           Average Compound Score  Average Negative Score  \
# 2                32             2   @reedhastings  Netflix, Inc.
# 3                 1             1   @reedhastings  Netflix, Inc.
# 4               191             1   @reedhastings  Netflix, Inc.
# 5               677             1   @reedhastings  Netflix, Inc.
# 6              1699             2   @reedhastings  Netflix, Inc.
# 7               645             1   @reedhastings  Netflix, Inc.
# 8                49             1   @reedhastings  Netflix, Inc.
# 9                12             1   @reedhastings  Netflix, Inc.
# 10              198             1   @reedhastings  Netflix, Inc.
# 11              822             1   @reedhastings  Netflix, Inc.
# 12              115             1   @reedhastings  Netflix, Inc.
# 13             2551             1   @reedhastings  Netflix, Inc.
# 14              271             1   @reedhastings  Netflix, Inc.
# 15                0             1   @reedhastings  Netflix, Inc.
# 16             5811             2   @reedhastings  Netflix, Inc.
# 17             1132             1   @reedhastings  Netflix, Inc.
# 18               31             1   @reedhastings  Netflix, Inc.
# 19              404             1   @reedhastings  Netflix, Inc.
# 20               33             1   @reedhastings  Netflix, Inc.
# 21               57             1   @reedhastings  Netflix, Inc.
# 22              170             1   @reedhastings  Netflix, Inc.
# 23               10             2   @reedhastings  Netflix, Inc.
# 24                6             1   @reedhastings  Netflix, Inc.
# 25               18             1   @reedhastings  Netflix, Inc.
# 26            37586             1   @reedhastings  Netflix, Inc.
# 27                4             1   @reedhastings  Netflix, Inc.
# 28              311             1   @reedhastings  Netflix, Inc.
# 29              150             2   @reedhastings  Netflix, Inc.
# ..              ...           ...             ...            ...
# 198             693             1   @sundarpichai     Google LLC
# 199               0             1   @reedhastings  Netflix, Inc.
# 200              66             1   @sundarpichai     Google LLC
# 201             296             1   @sundarpichai     Google LLC
# 202            1184             2   @sundarpichai     Google LLC
# 203             121             1   @sundarpichai     Google LLC
# 204             461             1   @sundarpichai     Google LLC
# 205             670             2   @sundarpichai     Google LLC
# 206            6055             3       @elonmusk    Tesla, Inc.
# 207            3669             7       @elonmusk    Tesla, Inc.
# 208           22037            19       @elonmusk    Tesla, Inc.
# 209           17778            21       @elonmusk    Tesla, Inc.
# 210            1376             1       @elonmusk    Tesla, Inc.
# 211           14027             3       @elonmusk    Tesla, Inc.
# 212           24427             7       @elonmusk    Tesla, Inc.
# 213            2519            10       @elonmusk    Tesla, Inc.
# 214            4191            12       @elonmusk    Tesla, Inc.
# 215             758             1       @elonmusk    Tesla, Inc.
# 216            3568             8       @elonmusk    Tesla, Inc.
# 217            4902             4       @elonmusk    Tesla, Inc.
# 218            9519            13       @elonmusk    Tesla, Inc.
# 219            2357             6       @elonmusk    Tesla, Inc.
# 220            2046             4       @elonmusk    Tesla, Inc.
# 221            4534             9       @elonmusk    Tesla, Inc.
# 222           86891            32       @elonmusk    Tesla, Inc.
# 223            2776             5       @elonmusk    Tesla, Inc.
# 224           13950            17       @elonmusk    Tesla, Inc.
# 225           24321             8       @elonmusk    Tesla, Inc.
# 226            3649            10       @elonmusk    Tesla, Inc.
# 227            1572             6       @elonmusk    Tesla, Inc.
#
# [228 rows x 10 columns]

# %%
#Save to csv file
tweets_data_summary.to_csv("Twitter_data.csv", index=False)

# %% [markdown]
# ### Online news

# %%
#Dependencies
from datetime import datetime
from datetime import date

import matplotlib.pyplot as plt
import pandas as pd
import json
import pprint

from newsapi.newsapi_client import NewsApiClient # API for searching for articles from over 30,000 news sources and blogs (https://newsapi.org/docs)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-7aa459a3f0f4> in <module>()
#       8 import pprint
#       9
# ---> 10 from newsapi.newsapi_client import NewsApiClient # API for searching for articles from over 30,000 news sources and blogs (https://newsapi.org/docs)
#
# ModuleNotFoundError: No module named 'newsapi.newsapi_client'

# %%
# Init
newsapi = NewsApiClient(api_key='3e89e595568a4616a16181234c5c4e25')

queries = ["google", "tesla", "netflix"]

authors = []
titles = []
descriptions = []
sources = []
publish_dates = []
topics = []

for query in range(len(queries)):
    all_articles = newsapi.get_everything(q=queries[query],
                                          #from_param='2019-03-01',
                                          from_param=str(date(datetime.today().year,(datetime.today().month - 1),(datetime.today().day + 1))),
                                          to=str(datetime.today()),
                                          language='en',
                                          sort_by='relevancy',
                                          page=5)    
    for num in range(len(all_articles['articles'])):
        topics.append(queries[query])
        authors.append(all_articles['articles'][num]['author'])
        titles.append(all_articles['articles'][num]['title'])
        descriptions.append(all_articles['articles'][num]['description'])
        sources.append(all_articles['articles'][num]['url'])
        publish_dates.append(str(all_articles['articles'][num]['publishedAt']).split("T")[0])

# %%
news_dict = {"Topic": topics,
             "Author": authors,
             "Title": titles,
             "Description": descriptions,
             "Source": sources,
             "Date": publish_dates}

news_df = pd.DataFrame(news_dict)

# %%
news_df["Company Name"] = ""
news_df.loc[news_df["Topic"] == "tesla", "Company Name"] = "Tesla, Inc."
news_df.loc[news_df["Topic"] == "google", "Company Name"] = "Google LLC"
news_df.loc[news_df["Topic"] == "netflix", "Company Name"] = "Netflix, Inc."

# %%
news_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-13c5cfba1a58> in <module>()
# ----> 1 news_df
#
# NameError: name 'news_df' is not defined

# %%
#News sentiment analysis

# Run vader analysis on each row in news df

news_df["Compound Score"] = ""
news_df["Positive Score"] = ""
news_df["Negative Score"] = ""
news_df["Neutral Score"] = ""

for index, row in news_df.iterrows():
    scores = analyzer.polarity_scores(row["Description"])
    row["Compound Score"] = scores["compound"]
    row["Positive Score"] = scores["pos"]
    row["Negative Score"] = scores["neu"]
    row["Neutral Score"] = scores["neg"]

# %%
news_df.dtypes
# Out:
# Topic             object
# Author            object
# Title             object
# Description       object
# Source            object
# Date              object
# Company Name      object
# Compound Score    object
# Positive Score    object
# Negative Score    object
# Neutral Score     object
# dtype: object

# %%
cols = ["Compound Score", "Positive Score", "Negative Score", "Neutral Score"]
news_df[cols] = news_df[cols].apply(pd.to_numeric, errors='coerce')

# %%
news_df.dtypes
# Out:
# Topic              object
# Author             object
# Title              object
# Description        object
# Source             object
# Date               object
# Company Name       object
# Compound Score    float64
# Positive Score    float64
# Negative Score    float64
# Neutral Score     float64
# dtype: object

# %%
#Data aggregation in order to figure out the total characteristics on the daily impacts of tweets by person
grouped_news_data = news_df.groupby(["Date"])

# %%
news_data_summary = pd.DataFrame({"Company Name": grouped_news_data["Company Name"].unique().str.get(0), 
                                  "Total News (per day)": grouped_news_data["Title"].count(),
                                  "Average Compound Score": grouped_news_data["Compound Score"].mean(),
                                  "Average Positive Score": grouped_news_data["Positive Score"].mean(),
                                  "Average Negative Score": grouped_news_data["Negative Score"].mean(),
                                  "Average Neutral Score": grouped_news_data["Neutral Score"].mean()
                                 })
news_data_summary.reset_index(inplace=True)
news_data_summary
# Out:
#           Date   Company Name  Total News (per day)  Average Compound Score  \
# 0   2019-03-02    Tesla, Inc.                     1               -0.962300
# 1   2019-03-03     Google LLC                     2                0.089150
# 2   2019-03-04     Google LLC                     1               -0.381800
# 3   2019-03-06    Tesla, Inc.                     1               -0.051600
# 4   2019-03-07    Tesla, Inc.                     3                0.809767
# 5   2019-03-08  Netflix, Inc.                     1                0.624900
# 6   2019-03-11    Tesla, Inc.                     3                0.224367
# 7   2019-03-12     Google LLC                     2                0.560900
# 8   2019-03-13     Google LLC                     1                0.796400
# 9   2019-03-14     Google LLC                     4               -0.522175
# 10  2019-03-15    Tesla, Inc.                     2                0.051250
# 11  2019-03-16     Google LLC                     2               -0.115150
# 12  2019-03-17    Tesla, Inc.                     1               -0.188200
# 13  2019-03-18    Tesla, Inc.                     2                0.179150
# 14  2019-03-19     Google LLC                     6                0.401933
# 15  2019-03-20     Google LLC                     2                0.359200
# 16  2019-03-21    Tesla, Inc.                     2               -0.113150
# 17  2019-03-22  Netflix, Inc.                     2                0.073500
# 18  2019-03-23     Google LLC                     4                0.574000
# 19  2019-03-24  Netflix, Inc.                     1                0.369100
# 20  2019-03-25    Tesla, Inc.                     2                0.044500
# 21  2019-03-27    Tesla, Inc.                     4               -0.127450
# 22  2019-03-28     Google LLC                     2                0.545000
# 23  2019-03-29     Google LLC                     3                0.068200
# 24  2019-03-30    Tesla, Inc.                     1               -0.077200
# 25  2019-03-31     Google LLC                     1                0.401900
# 26  2019-04-01     Google LLC                     4                0.270450
#
#     Average Positive Score  Average Negative Score  Average Neutral Score
# 0                 0.052000                0.534000               0.414000
# 1                 0.057500                0.893000               0.049500
# 2                 0.000000                0.917000               0.083000
# 3                 0.042000                0.911000               0.047000
# 4                 0.189667                0.810333               0.000000
# 5                 0.085000                0.915000               0.000000
# 6                 0.035333                0.964667               0.000000
# 7                 0.116000                0.861000               0.023000
# 8                 0.176000                0.824000               0.000000
# 9                 0.062250                0.763750               0.174000
# 10                0.090000                0.833000               0.076500
# 11                0.053000                0.873000               0.074000
# 12                0.053000                0.912000               0.034000
# 13                0.145000                0.830500               0.024500
# 14                0.149500                0.807500               0.042833
# 15                0.081000                0.919000               0.000000
# 16                0.029500                0.898500               0.072000
# 17                0.096500                0.824500               0.078500
# 18                0.145000                0.843750               0.011250
# 19                0.106000                0.819000               0.075000
# 20                0.058000                0.912000               0.030000
# 21                0.011000                0.919500               0.069500
# 22                0.097500                0.902500               0.000000
# 23                0.094000                0.779333               0.127000
# 24                0.053000                0.887000               0.060000
# 25                0.060000                0.940000               0.000000
# 26                0.134750                0.810500               0.054750

# %%
#Save to csv file
news_data_summary.to_csv("News_data.csv", index=False)

# %%
#Dependencies
from datetime import datetime
from datetime import date

import matplotlib.pyplot as plt
import pandas as pd
import json
import pprint
import requests

# %%
title = []
text = []
sentiment = []
sources = []
ticker_s = []
date = []

queries = ['TSLA' , 'GOOGL', 'NFLX']
url = 'https://stocknewsapi.com/api/v1'
token = 'esncnkofuqn3lfpiwwtrfzavmsmsnci9gf5t7jzd'
for query in range(len(queries)):
    ticker = queries[query]
    url = 'https://stocknewsapi.com/api/v1' 
    query_url = f"{url}?tickers={ticker}&items=50&fallback=true&token={token}"  
    #print(query_url)
    response = requests.get(query_url)
    news_articles = response.json()
    #print (response.json())
    query = query + 1
                            
    for num in range(len(news_articles['data'])):
#         topics.append(queries[query])
        #authors.append(all_articles['articles'][num]['author'])
        title.append(news_articles['data'][num]['title'])
        sentiment.append(news_articles['data'][num]['sentiment'])
        sources.append(news_articles['data'][num]['source_name'])
        ticker_s.append(news_articles['data'][num]['tickers'])
        date.append(str(news_articles['data'][num]['date']).split("T")[0])
        
news_dict = {"Title": title,
             "Author": sources,
             "Sentiment": sentiment,
             "ticker": ticker_s,
             "Source": sources,
             "Date": date}

news_df = pd.DataFrame(news_dict)

# %%
news_df
# Out:
#                             Author                             Date Sentiment  \
# 0                 24/7 Wall Street                                   Negative
# 1         Investors Business Daily                                   Negative
# 2                           Forbes                                   Negative
# 3    Bloomberg Markets and Finance                                   Negative
# 4                  CNBC Television                                    Neutral
# 5                  CNBC Television                                    Neutral
# 6                         Benzinga                                   Negative
# 7                             CNBC                                   Negative
# 8                     Fox Business                                    Neutral
# 9                             CNBC                                   Negative
# 10                            CNBC                                   Negative
# 11                    Fox Business                                   Negative
# 12                    Market Watch  Wed, 03 Apr 2019 20:17:52 -0400  Negative
# 13                            CNBC  Wed, 03 Apr 2019 20:15:00 -0400  Negative
# 14                 The Motley Fool  Wed, 03 Apr 2019 20:10:00 -0400  Positive
# 15            Bloomberg Technology  Wed, 03 Apr 2019 19:10:38 -0400  Positive
# 16                        Benzinga  Wed, 03 Apr 2019 16:21:13 -0400   Neutral
# 17                 CNBC Television  Wed, 03 Apr 2019 15:05:53 -0400  Positive
# 18                 The Motley Fool  Wed, 03 Apr 2019 14:01:00 -0400  Positive
# 19                 CNBC Television  Wed, 03 Apr 2019 13:20:06 -0400  Positive
# 20                 CNBC Television  Wed, 03 Apr 2019 10:09:05 -0400   Neutral
# 21                 CNBC Television  Wed, 03 Apr 2019 07:38:09 -0400   Neutral
# 22                            CNBC                                   Positive
# 23                 CNBC Television                                    Neutral
# 24                        Benzinga                                   Negative
# 25                 The Motley Fool                                    Neutral
# 26       Zacks Investment Research                                   Negative
# 27        Investors Business Daily                                   Negative
# 28                 CNBC Television                                   Negative
# 29                    Fox Business                                   Negative
# ..                             ...                              ...       ...
# 120                   Fox Business  Fri, 29 Mar 2019 13:15:45 -0400   Neutral
# 121                   Fox Business  Fri, 29 Mar 2019 11:49:22 -0400  Positive
# 122                  Seeking Alpha  Fri, 29 Mar 2019 09:46:12 -0400  Positive
# 123                CNBC Television                                   Negative
# 124                The Motley Fool                                    Neutral
# 125                The Motley Fool                                   Positive
# 7    Tesla delivery numbers indicate 2019 will be a...
# 8    Tesla CEO Elon Musk's volatile behavior a conc...
# 9    JP Morgan says Tesla just undermined Elon Musk...
# 10   Tesla plunges 8% after analysts say deliveries...
# 11                           Has Tesla lots its cache?
# 12   Tesla falls short of expectations for first-qu...
# 13   Tesla ships 63,000 vehicles in Q1, produced 77...
# 14   After-Hours News: Tesla Rolls Out Autopilot Fe...
# 15   Musk Appears More Stable and Seems to Have Tur...
# 16   Researchers Trick Tesla Autopilot Using Sticke...
# 17   These are LinkedIn's top companies to work for...
# 18   Tesla Will Show Off a Computer for Autonomous ...
# 19                                      Bulls on Tesla
# 20   Tesla bull and bear debate the stock as Elon M...
# 21   Tesla preview: Musk in court, Q1 Model 3 deliv...
# 22   Cramer: Charts show why Tesla's stock could be...
# 23   Here's what Tesla investors should watch ahead...
# 24   2 Key Technical Levels Tesla Investors Should ...
# 25   Driverless Cars' Biggest Obstacle May Be Us. H...
# 26                       Bear of the Day: Tesla (TSLA)
# 27                           U.S. Auto Sales: Slowdown
# 28   Judge may order Musk to step down as CEO, Oppe...
# 29       Tesla's shipping challenges for Europe, China
# ..                                                 ...
# 120       Netflix, Amazon leading to messier breakups?
# 121     Tech dominates list of most valuable US brands
# 122  Why Apple And Netflix Are Feeling The Streamin...
# 123  Big tech has achieved mass accumulation of pow...
# 124                             What Are FAANG Stocks?
# 125       Netflix's Plan to Win in India: Lower Prices
# 126  It's Disney -- Not Apple -- That Netflix Has t...
# 127               A Closer Look At Netflix's Valuation
# 128  Netflix: A Once-In-A-Generation Short Opportunity
# 129  Netflix's stock rallies, erasing previous loss...
# 130                          Apple to take on Netflix?
# 131                             Netflix By The Numbers
# 132  Almost Nobody Chooses Streaming Competitors Ov...
# 133  Netflix probably has too much of a head start ...
# 134  Everything coming to Netflix in April — and wh...
# 135                    Netflix: Competition Is Welcome
# 136                         Trading F.A.A.N.G.: 4 buys
# 137   Netflix Doesn't Have to Worry About Apple -- Yet
# 138  The Netflix Model Of Board Transparency: Is It...
# 139  Streaming content battle 'could get messy', sa...
# 140    4 Reasons RBC Continues To Love Netflix's Stock
# 141  Netflix drops 'Stranger Things' season 3 trail...
# 142  Netflix just dropped the ‘Stranger Things’ Sea...
# 143  As Apple enters the streaming wars, will Netfl...
# 144  Netflix Execs Welcome Competition From Apple W...
# 145  Final trades: CVS Health, Facebook, Netflix, &...
# 146     Netflix says it will not join Apple TV service
# 147  Apple streaming service won't offer Netflix su...
# 148  Netflix CEO Says Company Decided 'Not To Integ...
# 149         Calls to Break Up FAANG -- Except This One
#
#                                                 ticker
# 0                                               [TSLA]
# 1                                               [TSLA]
# 2                                               [TSLA]
# 3                                               [TSLA]
# 4                                               [TSLA]
# 5                                               [TSLA]
# 6                                               [TSLA]
# 7                                               [TSLA]
# 8                                               [TSLA]
# 9                                               [TSLA]
# 10                                              [TSLA]
# 11                                              [TSLA]
# 12                                              [TSLA]
# 13                                              [TSLA]
# 14                                              [TSLA]
# 15                                              [TSLA]
# 16                                              [TSLA]
# 17                                              [TSLA]
# 18                                              [TSLA]
# 19                                              [TSLA]
# 20                                              [TSLA]
# 21                                              [TSLA]
# 22                                              [TSLA]
# 23                                              [TSLA]
# 24                                              [TSLA]
# 25                       [GM, GOOG, GOOGL, LYFT, TSLA]
# 26                                              [TSLA]
# 27            [F, FCAU, GM, HMC, NIO, NSANY, TM, TSLA]
# 28                                              [TSLA]
# 29                                              [TSLA]
# ..                                                 ...
# 120                                             [NFLX]
# 121  [DIS, FB, FOX, GOOGL, HD, MSFT, NFLX, T, VZ, W...
# 122                                       [AAPL, NFLX]
# 123                      [AMZN, FB, GOOG, GOOGL, NFLX]
# 124                [AAPL, AMZN, FB, GOOG, GOOGL, NFLX]
# 125                                             [NFLX]
# 126                                  [AAPL, DIS, NFLX]
# 127                                             [NFLX]
# 128                                             [NFLX]
# 129                                             [NFLX]
# 130                                       [AAPL, NFLX]
# 131                                             [NFLX]
# 132                                             [NFLX]
# 133                                             [NFLX]
# 134                                             [NFLX]
# 135                                             [NFLX]
# 136                      [AMZN, FB, GOOG, GOOGL, NFLX]
# 137                                             [NFLX]
# 138                                             [NFLX]
# 139                       [AAPL, DIS, FOX, NFLX, FOXA]
# 140                                             [NFLX]
# 141                                             [NFLX]
# 142                                             [NFLX]
# 143                                       [AAPL, NFLX]
# 144                                             [NFLX]
# 145                               [CVS, EWW, FB, NFLX]
# 146                                             [NFLX]
# 147                                       [AAPL, NFLX]
# 148                                             [NFLX]
# 149                [AAPL, AMZN, FB, GOOG, GOOGL, NFLX]
#
# [150 rows x 6 columns]

# %%
news_df["Company Name"] = ""
news_df.loc[news_df["ticker"] == "[TSLA]", "Company Name"] = "Tesla, Inc."
news_df.loc[news_df["ticker"] == "[GOOGL]", "Company Name"] = "Google LLC"
news_df.loc[news_df["ticker"] == "[NFLX]", "Company Name"] = "Netflix, Inc."


news_df
# Out:
#                             Author                             Date Sentiment  \
# 0                 24/7 Wall Street                                   Negative
# 1         Investors Business Daily                                   Negative
# 2                           Forbes                                   Negative
# 3    Bloomberg Markets and Finance                                   Negative
# 4                  CNBC Television                                    Neutral
# 5                  CNBC Television                                    Neutral
# 6                         Benzinga                                   Negative
# 7                             CNBC                                   Negative
# 8                     Fox Business                                    Neutral
# 9                             CNBC                                   Negative
# 10                            CNBC                                   Negative
# 11                    Fox Business                                   Negative
# 12                    Market Watch  Wed, 03 Apr 2019 20:17:52 -0400  Negative
# 13                            CNBC  Wed, 03 Apr 2019 20:15:00 -0400  Negative
# 14                 The Motley Fool  Wed, 03 Apr 2019 20:10:00 -0400  Positive
# 15            Bloomberg Technology  Wed, 03 Apr 2019 19:10:38 -0400  Positive
# 16                        Benzinga  Wed, 03 Apr 2019 16:21:13 -0400   Neutral
# 17                 CNBC Television  Wed, 03 Apr 2019 15:05:53 -0400  Positive
# 18                 The Motley Fool  Wed, 03 Apr 2019 14:01:00 -0400  Positive
# 19                 CNBC Television  Wed, 03 Apr 2019 13:20:06 -0400  Positive
# 20                 CNBC Television  Wed, 03 Apr 2019 10:09:05 -0400   Neutral
# 21                 CNBC Television  Wed, 03 Apr 2019 07:38:09 -0400   Neutral
# 137                The Motley Fool
# 138                         Forbes
# 139                CNBC Television
# 140                       Benzinga
# 141                           CNBC
# 142                   Market Watch
# 143                CNBC Television
# 144                The Motley Fool
# 145                CNBC Television
# 146                           CNBC
# 147                   Market Watch
# 148                       Benzinga
# 149                The Motley Fool
#
#                                                  Title  \
# 0    Does Tesla’s Delivery Failure Warrant a 10% Ha...
# 1    Tesla Stock Drops As Vehicle Delivery Report D...
# 2    Tesla's Huge Sales Miss Exposes Its Negative C...
# 3    Tesla Analyst Kallo Doesn’t See Flagging Appet...
# 4    The court will play a balancing act in Tesla-S...
# 5    There's still opportunity in Tesla despite a r...
# 6    Tesla Could Be In For A 'Bumpy' Year After Q1 ...
# 7    Tesla delivery numbers indicate 2019 will be a...
# 8    Tesla CEO Elon Musk's volatile behavior a conc...
# 9    JP Morgan says Tesla just undermined Elon Musk...
# 10   Tesla plunges 8% after analysts say deliveries...
# 11                           Has Tesla lots its cache?
# 12   Tesla falls short of expectations for first-qu...
# 13   Tesla ships 63,000 vehicles in Q1, produced 77...
# 14   After-Hours News: Tesla Rolls Out Autopilot Fe...
# 15   Musk Appears More Stable and Seems to Have Tur...
# 16   Researchers Trick Tesla Autopilot Using Sticke...
# 17   These are LinkedIn's top companies to work for...
# 18   Tesla Will Show Off a Computer for Autonomous ...
# 19                                      Bulls on Tesla
# 20   Tesla bull and bear debate the stock as Elon M...
# 21   Tesla preview: Musk in court, Q1 Model 3 deliv...
# 22   Cramer: Charts show why Tesla's stock could be...
# 23   Here's what Tesla investors should watch ahead...
# 24   2 Key Technical Levels Tesla Investors Should ...
# 25   Driverless Cars' Biggest Obstacle May Be Us. H...
# 26                       Bear of the Day: Tesla (TSLA)
# 27                           U.S. Auto Sales: Slowdown
# 28   Judge may order Musk to step down as CEO, Oppe...
# 29       Tesla's shipping challenges for Europe, China
# ..                                                 ...
# 120       Netflix, Amazon leading to messier breakups?
# 121     Tech dominates list of most valuable US brands
# 122  Why Apple And Netflix Are Feeling The Streamin...
# 123  Big tech has achieved mass accumulation of pow...
# 124                             What Are FAANG Stocks?
# 125       Netflix's Plan to Win in India: Lower Prices
# 126  It's Disney -- Not Apple -- That Netflix Has t...
# 127               A Closer Look At Netflix's Valuation
# 128  Netflix: A Once-In-A-Generation Short Opportunity
# 129  Netflix's stock rallies, erasing previous loss...
# 130                          Apple to take on Netflix?
# 131                             Netflix By The Numbers
# 132  Almost Nobody Chooses Streaming Competitors Ov...
# 133  Netflix probably has too much of a head start ...
# 134  Everything coming to Netflix in April — and wh...
# 135                    Netflix: Competition Is Welcome
# 136                         Trading F.A.A.N.G.: 4 buys
# 137   Netflix Doesn't Have to Worry About Apple -- Yet
# 138  The Netflix Model Of Board Transparency: Is It...
# 139  Streaming content battle 'could get messy', sa...
# 140    4 Reasons RBC Continues To Love Netflix's Stock
# 141  Netflix drops 'Stranger Things' season 3 trail...
# 142  Netflix just dropped the ‘Stranger Things’ Sea...
# 143  As Apple enters the streaming wars, will Netfl...
# 144  Netflix Execs Welcome Competition From Apple W...
# 145  Final trades: CVS Health, Facebook, Netflix, &...
# 146     Netflix says it will not join Apple TV service
# 147  Apple streaming service won't offer Netflix su...
# 148  Netflix CEO Says Company Decided 'Not To Integ...
# 149         Calls to Break Up FAANG -- Except This One
#
#                                                 ticker Company Name
# 0                                               [TSLA]
# 1                                               [TSLA]
# 2                                               [TSLA]
# 3                                               [TSLA]
# 4                                               [TSLA]
# 5                                               [TSLA]
# 6                                               [TSLA]
# 7                                               [TSLA]
# 8                                               [TSLA]
# 9                                               [TSLA]
# 10                                              [TSLA]
# 11                                              [TSLA]
# 12                                              [TSLA]
# 13                                              [TSLA]
# 14                                              [TSLA]
# 15                                              [TSLA]
# 16                                              [TSLA]
# 17                                              [TSLA]
# 18                                              [TSLA]
# 19                                              [TSLA]
# 20                                              [TSLA]
# 21                                              [TSLA]
# 22                                              [TSLA]
# 23                                              [TSLA]
# 24                                              [TSLA]
# 25                       [GM, GOOG, GOOGL, LYFT, TSLA]
# 26                                              [TSLA]
# 27            [F, FCAU, GM, HMC, NIO, NSANY, TM, TSLA]
# 28                                              [TSLA]
# 29                                              [TSLA]
# ..                                                 ...          ...
# 120                                             [NFLX]
# 121  [DIS, FB, FOX, GOOGL, HD, MSFT, NFLX, T, VZ, W...
# 122                                       [AAPL, NFLX]
# 123                      [AMZN, FB, GOOG, GOOGL, NFLX]
# 124                [AAPL, AMZN, FB, GOOG, GOOGL, NFLX]
# 125                                             [NFLX]
# 126                                  [AAPL, DIS, NFLX]
# 127                                             [NFLX]
# 128                                             [NFLX]
# 129                                             [NFLX]
# 130                                       [AAPL, NFLX]
# 131                                             [NFLX]
# 132                                             [NFLX]
# 133                                             [NFLX]
# 134                                             [NFLX]
# 135                                             [NFLX]
# 136                      [AMZN, FB, GOOG, GOOGL, NFLX]
# 137                                             [NFLX]
# 138                                             [NFLX]
# 139                       [AAPL, DIS, FOX, NFLX, FOXA]
# 140                                             [NFLX]
# 141                                             [NFLX]
# 142                                             [NFLX]
# 143                                       [AAPL, NFLX]
# 144                                             [NFLX]
# 145                               [CVS, EWW, FB, NFLX]
# 146                                             [NFLX]
# 147                                       [AAPL, NFLX]
# 148                                             [NFLX]
# 149                [AAPL, AMZN, FB, GOOG, GOOGL, NFLX]
#
# [150 rows x 7 columns]

# %%
# Run vader analysis on each row in news df

news_df["Compound Score"] = ""
news_df["Positive Score"] = ""
news_df["Negative Score"] = ""
news_df["Neutral Score"] = ""

for index, row in news_df.iterrows():
    scores = analyzer.polarity_scores(row["Title"])
    row["Compound Score"] = scores["compound"]
    row["Positive Score"] = scores["pos"]
    row["Negative Score"] = scores["neu"]
    row["Neutral Score"] = scores["neg"]
    
cols = ["Compound Score", "Positive Score", "Negative Score", "Neutral Score"]
news_df[cols] = news_df[cols].apply(pd.to_numeric, errors='coerce')

#Data aggregation in order to figure out the total characteristics on the daily impacts of tweets by person
grouped_news_data = news_df.groupby(["Date"])

news_data_summary = pd.DataFrame({"Company Name": grouped_news_data["ticker"].unique().str.get(0), 
                                  "Total News (per day)": grouped_news_data["Title"].count(),
                                  "Average Compound Score": grouped_news_data["Compound Score"].mean(),
                                  "Average Positive Score": grouped_news_data["Positive Score"].mean(),
                                  "Average Negative Score": grouped_news_data["Negative Score"].mean(),
                                  "Average Neutral Score": grouped_news_data["Neutral Score"].mean()
                                 })
news_data_summary.reset_index(inplace=True)
news_data_summary
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/groupby.py in wrapper(*args, **kwargs)
#     722             try:
# --> 723                 return self.apply(curried_with_axis)
#     724             except Exception:
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/groupby.py in apply(self, func, *args, **kwargs)
#    3111     def apply(self, func, *args, **kwargs):
# -> 3112         return super(SeriesGroupBy, self).apply(func, *args, **kwargs)
#    3113
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/groupby.py in apply(self, func, *args, **kwargs)
#     804         with option_context('mode.chained_assignment', None):
# --> 805             return self._python_apply_general(f)
#     806
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/groupby.py in _python_apply_general(self, f)
#     808         keys, values, mutated = self.grouper.apply(f, self._selected_obj,
# --> 809                                                    self.axis)
#     810
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/groupby.py in apply(self, f, data, axis)
#    1968             group_axes = _get_axes(group)
# -> 1969             res = f(group)
#    1970             if not _is_indexed_like(res, group_axes):
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/groupby.py in curried_with_axis(x)
#     707             def curried_with_axis(x):
# --> 708                 return f(x, *args, **kwargs_with_axis)
#     709
#
# TypeError: unique() got an unexpected keyword argument 'axis'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/groupby.py in wrapper(*args, **kwargs)
#     725                 try:
# --> 726                     return self.apply(curried)
#     727                 except Exception:
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/groupby.py in apply(self, func, *args, **kwargs)
#    3111     def apply(self, func, *args, **kwargs):
# -> 3112         return super(SeriesGroupBy, self).apply(func, *args, **kwargs)
#    3113
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/groupby.py in apply(self, func, *args, **kwargs)
#     804         with option_context('mode.chained_assignment', None):
# --> 805             return self._python_apply_general(f)
#     806
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/groupby.py in _python_apply_general(self, f)
#     808         keys, values, mutated = self.grouper.apply(f, self._selected_obj,
# --> 809                                                    self.axis)
#     810
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/groupby.py in apply(self, f, data, axis)
#    1968             group_axes = _get_axes(group)
# -> 1969             res = f(group)
#    1970             if not _is_indexed_like(res, group_axes):
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/groupby.py in curried(x)
#     710             def curried(x):
# --> 711                 return f(x, *args, **kwargs)
#     712
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/series.py in unique(self)
#    1282     def unique(self):
# -> 1283         result = super(Series, self).unique()
#    1284
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/base.py in unique(self)
#     904             from pandas.core.algorithms import unique1d
# --> 905             result = unique1d(values)
#     906
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/algorithms.py in unique(values)
#     363     table = htable(len(values))
# --> 364     uniques = table.unique(values)
#     365     uniques = _reconstruct_data(uniques, dtype, original)
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.unique()
#
# TypeError: unhashable type: 'list'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/groupby.py in wrapper(*args, **kwargs)
#     735                     try:
# --> 736                         return self._aggregate_item_by_item(name,
#     737                                                             *args, **kwargs)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/groupby.py in __getattr__(self, attr)
#     675         raise AttributeError("%r object has no attribute %r" %
# --> 676                              (type(self).__name__, attr))
#     677
#
# AttributeError: 'SeriesGroupBy' object has no attribute '_aggregate_item_by_item'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-95af0b90acf2> in <module>()
#      21 grouped_news_data = news_df.groupby(["Date"])
#      22
# ---> 23 news_data_summary = pd.DataFrame({"Company Name": grouped_news_data["ticker"].unique().str.get(0),
#      24                                   "Total News (per day)": grouped_news_data["Title"].count(),
#      25                                   "Average Compound Score": grouped_news_data["Compound Score"].mean(),
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/groupby.py in wrapper(*args, **kwargs)
#     737                                                             *args, **kwargs)
#     738                     except (AttributeError):
# --> 739                         raise ValueError
#     740
#     741         return wrapper
#
# ValueError:

# %%
news_df.to_csv("News_API_sentiment.csv", index=False)
