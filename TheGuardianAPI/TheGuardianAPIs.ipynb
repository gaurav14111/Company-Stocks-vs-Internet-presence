# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json

# Import API key
from theguardian_api import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# %%
# Save config information.
url = "https://content.guardianapis.com/search?"
keyword = "adobe"
start_date = "2014-01-01"

# Build partial query URL
query_url = f"{url}q={keyword}&from-date={start_date}&api-key={api_key}"

# %%
response = requests.get(query_url).json()

# %%
print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# {
#     "response": {
#         "currentPage": 1,
#         "orderBy": "relevance",
#         "pageSize": 10,
#         "pages": 35,
#         "results": [
#             {
#                 "apiUrl": "https://content.guardianapis.com/technology/askjack/2019/jan/24/can-i-buy-a-monitor-for-photo-editing-that-shows-colour-like-print",
#                 "id": "technology/askjack/2019/jan/24/can-i-buy-a-monitor-for-photo-editing-that-shows-colour-like-print",
#                 "isHosted": false,
#                 "pillarId": "pillar/news",
#                 "pillarName": "News",
#                 "sectionId": "technology",
#                 "sectionName": "Technology",
#                 "type": "article",
#                 "webPublicationDate": "2019-01-24T08:00:00Z",
#                 "webTitle": "Can I buy a monitor for photo editing that shows colour like print?",
#                 "webUrl": "https://www.theguardian.com/technology/askjack/2019/jan/24/can-i-buy-a-monitor-for-photo-editing-that-shows-colour-like-print"
#             },
#             {
#                 "apiUrl": "https://content.guardianapis.com/artanddesign/2018/dec/20/living-coral-pantone-colour-of-the-year-for-2019",
#                 "id": "artanddesign/2018/dec/20/living-coral-pantone-colour-of-the-year-for-2019",
#                 "isHosted": false,
#                 "pillarId": "pillar/arts",
#                 "pillarName": "Arts",
#                 "sectionId": "artanddesign",
#                 "sectionName": "Art and design",
#                 "type": "article",
#                 "webPublicationDate": "2018-12-20T07:00:26Z",
#                 "webTitle": "Living coral: Pantone's colour of the year for 2019",
#                 "webUrl": "https://www.theguardian.com/artanddesign/2018/dec/20/living-coral-pantone-colour-of-the-year-for-2019"
#             },
#             {
#                 "apiUrl": "https://content.guardianapis.com/fashion/shortcuts/2018/dec/06/living-coral-pantone-colour-of-the-year-2019",
#                 "id": "fashion/shortcuts/2018/dec/06/living-coral-pantone-colour-of-the-year-2019",
#                 "isHosted": false,
#                 "pillarId": "pillar/lifestyle",
#                 "pillarName": "Lifestyle",
#                 "sectionId": "fashion",
#                 "sectionName": "Fashion",
#                 "type": "article",
#                 "webPublicationDate": "2018-12-06T08:31:26Z",
#                 "webTitle": "Living coral: Pantone's 2019 colour of the year",
#                 "webUrl": "https://www.theguardian.com/fashion/shortcuts/2018/dec/06/living-coral-pantone-colour-of-the-year-2019"
#             },
#             {
#                 "apiUrl": "https://content.guardianapis.com/lifeandstyle/shortcuts/2018/nov/02/how-to-make-your-bonfire-night-photos-sparkle",
#                 "id": "lifeandstyle/shortcuts/2018/nov/02/how-to-make-your-bonfire-night-photos-sparkle",
#                 "isHosted": false,
#                 "pillarId": "pillar/lifestyle",
#                 "pillarName": "Lifestyle",
#                 "sectionId": "lifeandstyle",
#                 "sectionName": "Life and style",
#                 "type": "article",
#                 "webPublicationDate": "2018-11-02T16:02:29Z",
#                 "webTitle": "How to make your bonfire night photos sparkle",
#                 "webUrl": "https://www.theguardian.com/lifeandstyle/shortcuts/2018/nov/02/how-to-make-your-bonfire-night-photos-sparkle"
#             },
#             {
#                 "apiUrl": "https://content.guardianapis.com/technology/shortcuts/2018/aug/27/re-attaching-for-convenience-passive-aggressive-email-phrases-poll",
#                 "id": "technology/shortcuts/2018/aug/27/re-attaching-for-convenience-passive-aggressive-email-phrases-poll",
#                 "isHosted": false,
#                 "pillarId": "pillar/news",
#                 "pillarName": "News",
#                 "sectionId": "technology",
#                 "sectionName": "Technology",
#                 "type": "article",
#                 "webPublicationDate": "2018-08-27T13:03:26Z",
#                 "webTitle": "\u2018Reattaching for convenience\u2019: nine passive-aggressive email phrases that must end now",
#                 "webUrl": "https://www.theguardian.com/technology/shortcuts/2018/aug/27/re-attaching-for-convenience-passive-aggressive-email-phrases-poll"
#             },
#             {
#                 "apiUrl": "https://content.guardianapis.com/commentisfree/2018/aug/28/passive-aggressive-break-email-chain",
#                 "id": "commentisfree/2018/aug/28/passive-aggressive-break-email-chain",
#                 "isHosted": false,
#                 "pillarId": "pillar/opinion",
#                 "pillarName": "Opinion",
#                 "sectionId": "commentisfree",
#                 "sectionName": "Opinion",
#                 "type": "article",
#                 "webPublicationDate": "2018-08-28T10:30:08Z",
#                 "webTitle": "As discussed: it\u2019s time to break the hateful passive-aggressive email chain | Andr\u00e9 Spicer",
#                 "webUrl": "https://www.theguardian.com/commentisfree/2018/aug/28/passive-aggressive-break-email-chain"
#             },
#             {
#                 "apiUrl": "https://content.guardianapis.com/technology/askjack/2018/feb/22/would-cheap-refurbished-laptop-run-photoshop-adobe-creative-suite-graphic-design",
#                 "id": "technology/askjack/2018/feb/22/would-cheap-refurbished-laptop-run-photoshop-adobe-creative-suite-graphic-design",
#                 "isHosted": false,
#                 "pillarId": "pillar/news",
#                 "pillarName": "News",
#                 "sectionId": "technology",
#                 "sectionName": "Technology",
#                 "type": "article",
#                 "webPublicationDate": "2018-02-22T10:56:32Z",
#                 "webTitle": "Would a cheap refurbished laptop run Photoshop?",
#                 "webUrl": "https://www.theguardian.com/technology/askjack/2018/feb/22/would-cheap-refurbished-laptop-run-photoshop-adobe-creative-suite-graphic-design"
#             },
#             {
#                 "apiUrl": "https://content.guardianapis.com/environment/2018/may/28/national-parks-are-more-than-natural",
#                 "id": "environment/2018/may/28/national-parks-are-more-than-natural",
#                 "isHosted": false,
#                 "pillarId": "pillar/news",
#                 "pillarName": "News",
#                 "sectionId": "environment",
#                 "sectionName": "Environment",
#                 "type": "article",
#                 "webPublicationDate": "2018-05-28T16:04:39Z",
#                 "webTitle": "National parks are more than natural | Letters",
#                 "webUrl": "https://www.theguardian.com/environment/2018/may/28/national-parks-are-more-than-natural"
#             },
#             {
#                 "apiUrl": "https://content.guardianapis.com/world/2019/feb/25/yazidis-isis-female-only-commune-jinwar-syria",
#                 "id": "world/2019/feb/25/yazidis-isis-female-only-commune-jinwar-syria",
#                 "isHosted": false,
#                 "pillarId": "pillar/news",
#                 "pillarName": "News",
#                 "sectionId": "world",
#                 "sectionName": "World news",
#                 "type": "article",
#                 "webPublicationDate": "2019-02-25T09:45:03Z",
#                 "webTitle": "'We are now free': Yazidis fleeing Isis start over in female-only commune",
#                 "webUrl": "https://www.theguardian.com/world/2019/feb/25/yazidis-isis-female-only-commune-jinwar-syria"
#             },
#             {
#                 "apiUrl": "https://content.guardianapis.com/technology/2018/aug/02/macs-ipods-apps-how-apple-revolutionised-technology",
#                 "id": "technology/2018/aug/02/macs-ipods-apps-how-apple-revolutionised-technology",
#                 "isHosted": false,
#                 "pillarId": "pillar/news",
#                 "pillarName": "News",
#                 "sectionId": "technology",
#                 "sectionName": "Technology",
#                 "type": "article",
#                 "webPublicationDate": "2018-08-02T16:03:49Z",
#                 "webTitle": "From Macs to iPods and apps: how Apple revolutionised technology",
#                 "webUrl": "https://www.theguardian.com/technology/2018/aug/02/macs-ipods-apps-how-apple-revolutionised-technology"
#             }
#         ],
#         "startIndex": 1,
#         "status": "ok",
#         "total": 347,
#         "userTier": "developer"
#     }
# }

# %%
from theguardian import theguardian_content

# create content with filters
# for more filters refer
# http://open-platform.theguardian.com/documentation/search

headers = {
    "q": "adobe",
    "from-date": "2014-01-01",
    "order-by": "relevance",
    "show-fields": "starRating,headline,thumbnail,short-url",
}
content = theguardian_content.Content(api=api_key, **headers)

res = content.get_content_response()
result = content.get_results(res)

print(json.dumps(result, indent=4, sort_keys=True))
# Out:
# [
#     {
#         "apiUrl": "https://content.guardianapis.com/technology/askjack/2019/jan/24/can-i-buy-a-monitor-for-photo-editing-that-shows-colour-like-print",
#         "fields": {
#             "headline": "Can I buy a monitor for photo editing that shows colour like print?",
#             "shortUrl": "https://gu.com/p/ahv2k",
#             "thumbnail": "https://media.guim.co.uk/da22c2d97abb78fa84079c25154eb6dd387da884/193_105_1194_716/500.jpg"
#         },
#         "id": "technology/askjack/2019/jan/24/can-i-buy-a-monitor-for-photo-editing-that-shows-colour-like-print",
#         "isHosted": false,
#         "pillarId": "pillar/news",
#         "pillarName": "News",
#         "sectionId": "technology",
#         "sectionName": "Technology",
#         "type": "article",
#         "webPublicationDate": "2019-01-24T08:00:00Z",
#         "webTitle": "Can I buy a monitor for photo editing that shows colour like print?",
#         "webUrl": "https://www.theguardian.com/technology/askjack/2019/jan/24/can-i-buy-a-monitor-for-photo-editing-that-shows-colour-like-print"
#     },
#     {
#         "apiUrl": "https://content.guardianapis.com/artanddesign/2018/dec/20/living-coral-pantone-colour-of-the-year-for-2019",
#         "fields": {
#             "headline": "Living coral: Pantone's colour of the year for 2019",
#             "shortUrl": "https://gu.com/p/a8djk",
#             "thumbnail": "https://media.guim.co.uk/376c63a2d8a0390639031a24445bf4f1df1750c6/336_0_6147_3689/500.jpg"
#         },
#         "id": "artanddesign/2018/dec/20/living-coral-pantone-colour-of-the-year-for-2019",
#         "isHosted": false,
#         "pillarId": "pillar/arts",
#         "pillarName": "Arts",
#         "sectionId": "artanddesign",
#         "sectionName": "Art and design",
#         "type": "article",
#         "webPublicationDate": "2018-12-20T07:00:26Z",
#         "webTitle": "Living coral: Pantone's colour of the year for 2019",
#         "webUrl": "https://www.theguardian.com/artanddesign/2018/dec/20/living-coral-pantone-colour-of-the-year-for-2019"
#     },
#     {
#         "apiUrl": "https://content.guardianapis.com/fashion/shortcuts/2018/dec/06/living-coral-pantone-colour-of-the-year-2019",
#         "fields": {
#             "headline": "Living coral: Pantone's 2019 colour of the year",
#             "shortUrl": "https://gu.com/p/a58vx",
#             "thumbnail": "https://media.guim.co.uk/1e83ceb895a970ea4f6871b10613d16608712b83/0_0_5354_3213/500.jpg"
#         },
#         "id": "fashion/shortcuts/2018/dec/06/living-coral-pantone-colour-of-the-year-2019",
#         "isHosted": false,
#         "pillarId": "pillar/lifestyle",
#         "pillarName": "Lifestyle",
#         "sectionId": "fashion",
#         "sectionName": "Fashion",
#         "type": "article",
#         "webPublicationDate": "2018-12-06T08:31:26Z",
#         "webTitle": "Living coral: Pantone's 2019 colour of the year",
#         "webUrl": "https://www.theguardian.com/fashion/shortcuts/2018/dec/06/living-coral-pantone-colour-of-the-year-2019"
#     },
#     {
#         "apiUrl": "https://content.guardianapis.com/lifeandstyle/shortcuts/2018/nov/02/how-to-make-your-bonfire-night-photos-sparkle",
#         "fields": {
#             "headline": "How to make your bonfire night photos sparkle",
#             "shortUrl": "https://gu.com/p/9z9xv",
#             "thumbnail": "https://media.guim.co.uk/bb1839391179603a49ae416b88d7af696861b406/0_415_4358_2613/500.jpg"
#         },
#         "id": "lifeandstyle/shortcuts/2018/nov/02/how-to-make-your-bonfire-night-photos-sparkle",
#         "isHosted": false,
#         "pillarId": "pillar/lifestyle",
#         "pillarName": "Lifestyle",
#         "sectionId": "lifeandstyle",
#         "sectionName": "Life and style",
#         "type": "article",
#         "webPublicationDate": "2018-11-02T16:02:29Z",
#         "webTitle": "How to make your bonfire night photos sparkle",
#         "webUrl": "https://www.theguardian.com/lifeandstyle/shortcuts/2018/nov/02/how-to-make-your-bonfire-night-photos-sparkle"
#     },
#     {
#         "apiUrl": "https://content.guardianapis.com/technology/shortcuts/2018/aug/27/re-attaching-for-convenience-passive-aggressive-email-phrases-poll",
#         "fields": {
#             "headline": "\u2018Reattaching for convenience\u2019: nine passive-aggressive email phrases that must end now",
#             "shortUrl": "https://gu.com/p/98qxf",
#             "thumbnail": "https://media.guim.co.uk/29119c54491c7dd29a88e413d1bc3ee012359569/0_163_5018_3011/500.jpg"
#         },
#         "id": "technology/shortcuts/2018/aug/27/re-attaching-for-convenience-passive-aggressive-email-phrases-poll",
#         "isHosted": false,
#         "pillarId": "pillar/news",
#         "pillarName": "News",
#         "sectionId": "technology",
#         "sectionName": "Technology",
#         "type": "article",
#         "webPublicationDate": "2018-08-27T13:03:26Z",
#         "webTitle": "\u2018Reattaching for convenience\u2019: nine passive-aggressive email phrases that must end now",
#         "webUrl": "https://www.theguardian.com/technology/shortcuts/2018/aug/27/re-attaching-for-convenience-passive-aggressive-email-phrases-poll"
#     },
#     {
#         "apiUrl": "https://content.guardianapis.com/commentisfree/2018/aug/28/passive-aggressive-break-email-chain",
#         "fields": {
#             "headline": "As discussed: it\u2019s time to break the hateful passive-aggressive email chain",
#             "shortUrl": "https://gu.com/p/99v88",
#             "thumbnail": "https://media.guim.co.uk/57947b47ed993c62bb7a838572d603bfb604920b/0_754_6400_3840/500.jpg"
#         },
#         "id": "commentisfree/2018/aug/28/passive-aggressive-break-email-chain",
#         "isHosted": false,
#         "pillarId": "pillar/opinion",
#         "pillarName": "Opinion",
#         "sectionId": "commentisfree",
#         "sectionName": "Opinion",
#         "type": "article",
#         "webPublicationDate": "2018-08-28T10:30:08Z",
#         "webTitle": "As discussed: it\u2019s time to break the hateful passive-aggressive email chain | Andr\u00e9 Spicer",
#         "webUrl": "https://www.theguardian.com/commentisfree/2018/aug/28/passive-aggressive-break-email-chain"
#     },
#     {
#         "apiUrl": "https://content.guardianapis.com/technology/askjack/2018/feb/22/would-cheap-refurbished-laptop-run-photoshop-adobe-creative-suite-graphic-design",
#         "fields": {
#             "headline": "Would a cheap refurbished laptop run Photoshop?",
#             "shortUrl": "https://gu.com/p/8636f",
#             "thumbnail": "https://media.guim.co.uk/19e310b231cd48047dd1659a8e8f628d6a21d321/352_534_3140_1884/500.jpg"
#         },
#         "id": "technology/askjack/2018/feb/22/would-cheap-refurbished-laptop-run-photoshop-adobe-creative-suite-graphic-design",
#         "isHosted": false,
#         "pillarId": "pillar/news",
#         "pillarName": "News",
#         "sectionId": "technology",
#         "sectionName": "Technology",
#         "type": "article",
#         "webPublicationDate": "2018-02-22T10:56:32Z",
#         "webTitle": "Would a cheap refurbished laptop run Photoshop?",
#         "webUrl": "https://www.theguardian.com/technology/askjack/2018/feb/22/would-cheap-refurbished-laptop-run-photoshop-adobe-creative-suite-graphic-design"
#     },
#     {
#         "apiUrl": "https://content.guardianapis.com/environment/2018/may/28/national-parks-are-more-than-natural",
#         "fields": {
#             "headline": "National parks are more than natural",
#             "shortUrl": "https://gu.com/p/8y6db",
#             "thumbnail": "https://media.guim.co.uk/37d54689493840bedfc7a3c97b4fd8d2f5aa3ff7/0_200_6000_3600/500.jpg"
#         },
#         "id": "environment/2018/may/28/national-parks-are-more-than-natural",
#         "isHosted": false,
#         "pillarId": "pillar/news",
#         "pillarName": "News",
#         "sectionId": "environment",
#         "sectionName": "Environment",
#         "type": "article",
#         "webPublicationDate": "2018-05-28T16:04:39Z",
#         "webTitle": "National parks are more than natural | Letters",
#         "webUrl": "https://www.theguardian.com/environment/2018/may/28/national-parks-are-more-than-natural"
#     },
#     {
#         "apiUrl": "https://content.guardianapis.com/world/2019/feb/25/yazidis-isis-female-only-commune-jinwar-syria",
#         "fields": {
#             "headline": "'We are now free': Yazidis fleeing Isis start over in female-only commune",
#             "shortUrl": "https://gu.com/p/aznjc",
#             "thumbnail": "https://media.guim.co.uk/da70fc332cbef5d811ec418d88bbc14cd0d69670/0_227_3264_1958/500.jpg"
#         },
#         "id": "world/2019/feb/25/yazidis-isis-female-only-commune-jinwar-syria",
#         "isHosted": false,
#         "pillarId": "pillar/news",
#         "pillarName": "News",
#         "sectionId": "world",
#         "sectionName": "World news",
#         "type": "article",
#         "webPublicationDate": "2019-02-25T09:45:03Z",
#         "webTitle": "'We are now free': Yazidis fleeing Isis start over in female-only commune",
#         "webUrl": "https://www.theguardian.com/world/2019/feb/25/yazidis-isis-female-only-commune-jinwar-syria"
#     },
#     {
#         "apiUrl": "https://content.guardianapis.com/technology/2018/aug/02/macs-ipods-apps-how-apple-revolutionised-technology",
#         "fields": {
#             "headline": "From Macs to iPods and apps: how Apple revolutionised technology",
#             "shortUrl": "https://gu.com/p/94ak6",
#             "thumbnail": "https://media.guim.co.uk/586c45daad5eb19901fabc507895bceba602b286/76_53_2913_1749/500.jpg"
#         },
#         "id": "technology/2018/aug/02/macs-ipods-apps-how-apple-revolutionised-technology",
#         "isHosted": false,
#         "pillarId": "pillar/news",
#         "pillarName": "News",
#         "sectionId": "technology",
#         "sectionName": "Technology",
#         "type": "article",
#         "webPublicationDate": "2018-08-02T16:03:49Z",
#         "webTitle": "From Macs to iPods and apps: how Apple revolutionised technology",
#         "webUrl": "https://www.theguardian.com/technology/2018/aug/02/macs-ipods-apps-how-apple-revolutionised-technology"
#     }
# ]

# %%
print(json.dumps(result, indent=4, sort_keys=True))
